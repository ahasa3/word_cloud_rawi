# %%
import pandas as pd
from find_rawi import find_perawi

# %% [markdown]
# # import dataset

# %%
path='D:/python/dataset_hadits/'

# %%
df=pd.read_csv(f'{path}shahih_bukhari.csv',sep=';' )
df
# Out:
#         id           kitab                                               arab  \
# 0        1  shahih_bukhari  حَدَّثَنَا الْحُمَيْدِيُّ عَبْدُ اللَّهِ بْنُ ...
# 1        2  shahih_bukhari  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ يُوسُفَ قَالَ أ...
# 2        3  shahih_bukhari  حَدَّثَنَا يَحْيَى بْنُ بُكَيْرٍ قَالَ حَدَّثَ...
# 3        4  shahih_bukhari  حَدَّثَنَا مُوسَى بْنُ إِسْمَاعِيلَ قَالَ حَدّ...
# 4        5  shahih_bukhari  حَدَّثَنَا عَبْدَانُ قَالَ أَخْبَرَنَا عَبْدُ ...
# ...    ...             ...                                                ...
# 7003  7004  shahih_bukhari  حَدَّثَنَا مُحَمَّدُ بْنُ الْعَلَاءِ حَدَّثَنَ...
# 7004  7005  shahih_bukhari  حَدَّثَنَا هُدْبَةُ بْنُ خَالِدٍ حَدَّثَنَا هَ...
# 7005  7006  shahih_bukhari  حَدَّثَنَا عَلِيٌّ حَدَّثَنَا هِشَامٌ أَخْبَرَ...
# 7006  7007  shahih_bukhari  حَدَّثَنَا أَبُو النُّعْمَانِ حَدَّثَنَا مَهْد...
# 7007  7008  shahih_bukhari  حَدَّثَنِي أَحْمَدُ بْنُ إِشْكَابٍ حَدَّثَنَا ...
#
#                                                terjemah
# 0     Telah menceritakan kepada kami [Al Humaidi Abd...
# 1     Telah menceritakan kepada kami [Abdullah bin Y...
# 2     Telah menceritakan kepada kami [Yahya bin Buka...
# 3     Telah menceritakan kepada kami [Musa bin Isma'...
# 4     Telah menceritakan kepada kami [Abdan] dia ber...
# ...                                                 ...
# 7003  Telah menceritakan kepada kami [Muhammad bin A...
# 7004  Telah menceritakan kepada kami [Hudbah bin Kha...
# 7005  Telah menceritakan kepada kami [Ali] telah men...
# 7006  Telah menceritakan kepada kami [Abu Nu'man] te...
# 7007  Telah menceritakan kepadaku [Ahmad bin Isykab]...
#
# [7008 rows x 4 columns]

# %% [markdown]
# # Mencari Perawi dan matan dari hadits

# %%
perawi = []
matan = []
for i,hadis in enumerate(df.terjemah.tolist()):
    r,m = find_perawi(hadis)
    perawi.append(r)
    if m == []:
        matan.append('Kosong')
    else:
        matan.append(m[0])
perawi
# Out:
# [['al humaidi abdullah bin az zubair',
#   'sufyan',
#   "yahya bin sa'id al anshari",
#   'muhammad bin ibrahim at taimi',
#   'alqamah bin waqash al laitsi',
#   'umar bin al khaththab'],
#  ['abdullah bin yusuf',
#   'malik',
#   "hisyam bin 'urwah",
#   'bapaknya',
#   'aisyah',
#   'harits bin hisyam'],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'urwah bin az zubair",
#   'aisyah'],
#  ["musa bin isma'il",
#   "abu 'awanah",
#   'musa bin abu aisyah',
#   "sa'id bin jubair",
#   "ibnu 'abbas"],
#  ['abdan',
#   'abdullah',
#   'yunus',
#   'az zuhri',
#   'bisyir bin muhammad',
#   'abdullah',
#   'yunus',
#   "ma'mar",
#   'ubaidullah bin abdullah',
#   "ibnu 'abbas"],
#  ["abu al yaman al hakam bin nafi'",
#   "syu'aib",
#   'az zuhri',
#   "ubaidullah bin abdullah bin 'utbah bin mas'ud",
#   "abdullah bin 'abbas",
#   'abu sufyan bin harb'],
#  ['abdullah bin musa',
#   'hanzhalah bin abu sufyan',
#   "'ikrimah bin khalid",
#   'ibnu umar'],
#  ["abdullah bin muhammad al ju'fi",
#   "abu 'amir al 'aqadi",
#   'sulaiman bin bilal',
#   'abdullah bin dinar',
#   'abu shalih',
#   'abu hurairah'],
#  ['adam bin abu iyas',
#   "syu'bah",
#   'abdullah bin abu as safar',
#   "asy sya'bi",
#   "abdullah bin 'amru"],
#  ["sa'id bin yahya bin sa'id al qurasyi",
#   'bapakku',
#   'abu burdah bin abdullah bin abu burdah',
#   'abu burdah',
#   'abu musa'],
#  ["'amru bin khalid",
#   'al laits',
#   'yazid',
#   'abu al khair',
#   "abdullah bin 'amru"],
#  ['musaddad', 'yahya', "syu'bah", 'qotadah', 'anas'],
#  ['abu al yaman', "syu'aib", 'abu az zanad', "al a'raj", 'abu hurairah'],
#  ["ya'qub bin ibrahim", "ibnu 'ulayyah", "abdul 'aziz bin shuhaib", 'anas'],
#  ['muhammad bin al mutsanna',
#   'abdul wahhab ats tsaqafi',
#   'ayyub',
#   'abu qilabah',
#   'anas bin malik'],
#  ['abu al walid', "syu'bah", 'abdullah bin abdullah bin jabar', 'anas'],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "abu idris 'aidzullah bin abdullah",
#   "'ubadah bin ash shamit"],
#  ['abdullah bin maslamah',
#   'malik',
#   "abdurrahman bin abdullah bin abdurrahman bin abu sha'sha'ah",
#   'bapaknya',
#   "abu sa'id al khudri"],
#  ['muhammad bin salam', "'abdah", 'hisyam', 'bapaknya', 'aisyah'],
#  ['sulaiman bin harb', "syu'bah", 'qotadah', 'anas bin malik'],
#  ["isma'il",
#   'malik',
#   "'amru bin yahya al mazani",
#   'bapaknya',
#   "abu sa'id al khudri"],
#  ['muhammad bin ubaidillah',
#   "ibrahim bin sa'd",
#   'shalih',
#   'ibnu syihab',
#   'abu umamah bin sahal bin hunaif',
#   'abu said al khudri'],
#  ['abdullah bin yusuf',
#   'malik bin anas',
#   'ibnu syihab',
#   'salim bin abdullah',
#   'bapaknya'],
#  ['abdullah bin muhammad al musnadi',
#   'abu rauh al harami bin umarah',
#   "syu'bah",
#   'waqid bin muhammad',
#   'bapakku',
#   'ibnu umar'],
#  ['ahmad bin yunus',
#   "ibrahim bin sa'd",
#   'ibnu syihab',
#   "sa'id bin al musayyab",
#   'abu hurairah'],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "'amir bin sa'd bin abu waqash",
#   "sa'd"],
#  ['qutaibah',
#   'al laits',
#   'yazid bin abu habib',
#   'abu al khair',
#   "abdullah bin 'amru"],
#  ['abdullah bin maslamah',
#   'malik',
#   'zaid bin aslam',
#   "'atho' bin yasar",
#   "ibnu 'abbas"],
#  ['sulaiman bin harb',
#   "syu'bah",
#   'washil al ahdab',
#   "al ma'rur bin suwaid",
#   'abu dzar'],
#  ['abdurrahman bin al mubarak',
#   'hammad bin zaid',
#   'ayyub',
#   'yunus',
#   'al hasan',
#   'al ahnaf bin qais',
#   'abu bakrah'],
#  ['abu al walid',
#   "syu'bah",
#   "bisyir bin khalid abu muhammad al 'asykari",
#   "muhammad bin ja'far",
#   "syu'bah",
#   'sulaiman',
#   'ibrahim',
#   'alqamah',
#   'abdullah'],
#  ["sulaiman abu ar rabi'",
#   "isma'il bin ja'far",
#   "nafi' bin malik bin abu 'amir abu suhail",
#   'bapaknya',
#   'abu hurairah'],
#  ["qabishah bin 'uqbah",
#   'sufyan',
#   "al a'masy",
#   'abdullah bin murrah',
#   'masruq',
#   "abdullah bin 'amru"],
#  ['abu al yaman', "syu'aib", 'abu al zanad', "al a'raj", 'abu hurairah'],
#  ['harami bin hafsh',
#   'abdul wahid',
#   'umarah',
#   "abu zur'ah bin 'amru bin jarir",
#   'abu hurairah'],
#  ["isma'il", 'malik', 'ibnu syihab', 'humaid bin abdurrahman', 'abu hurairah'],
#  ['muhammad bin salam',
#   'muhammad bin fudlail',
#   "yahya bin sa'id",
#   'abu salamah',
#   'abu hurairah'],
#  ['abdus salam bin muthahhar',
#   'umar bin ali',
#   "ma'an bin muhammad al ghifari",
#   "sa'id bin abu sa'id al maqburi",
#   'abu hurairah'],
#  ["'amru bin khalid", 'zuhair', 'abu ishaq', "al barro` bin 'azib"],
#  ['ishaq bin manshur',
#   'abdurrazzaq',
#   "ma'mar",
#   'hamam bin munabbih',
#   'abu hurairah'],
#  ['muhammad bin al mutsanna', 'yahya', 'hisyam', 'bapakku', 'aisyah'],
#  ['muslim bin ibrahim', 'hisyam', 'qotadah', 'anas'],
#  ['al hasan bin ash shabbah',
#   "ja'far bin 'aun",
#   "abu al 'umais",
#   'qais bin muslim',
#   'thariq bin syihab',
#   'umar bin al khaththab',
#   'umar bin al'],
#  ["isma'il",
#   'malik bin anas',
#   'abu suhail bin malik',
#   'bapaknya',
#   "thalhah bin 'ubaidullah"],
#  ['ahmad bin abdullah bin ali al manjufi',
#   'rauh',
#   "'auf",
#   'al hasan',
#   'abu hurairah'],
#  ["muhammad bin 'ar'arah", "syu'bah", 'zubaid', "abu wa'il", 'abdullah'],
#  ["qutaibah bin sa'id",
#   "isma'il bin ja'far",
#   'humaid',
#   'anas bin malik',
#   "'ubadah bin ash shamit"],
#  ['musaddad',
#   "isma'il bin ibrahim",
#   'abu hayyan at taimi',
#   "abu zur'ah",
#   'abu hurairah'],
#  ['ibrahim bin hamzah',
#   "ibrahim bin sa'd",
#   'shalih',
#   'ibnu syihab',
#   'ubaidillah bin abdullah',
#   "abdullah bin 'abbas",
#   'abu sufyan bin harb'],
#  ["abu nu'aim", 'zakaria', "'amir", "an nu'man bin basyir"],
#  ["ali bin al ja'di", "syu'bah", 'abu jamrah', "ibnu 'abbas"],
#  ['abdullah bin maslamah',
#   'malik',
#   "yahya bin sa'id",
#   'muhammad bin ibrahim',
#   'alqamah bin waqash',
#   'umar'],
#  ['hajjaj bin minhal',
#   "syu'bah",
#   "'adi bin tsabit",
#   'abdullah bin yazid',
#   "abu mas'ud"],
#  ["al hakam bin nafi'",
#   "syu'aib",
#   'az zuhri',
#   "'amir bin sa'd",
#   "sa'd bin abu waqash"],
#  ['musaddad', 'yahya', "isma'il", 'qais bin abu hazim', 'jarir bin abdullah'],
#  ["abu an nu'man",
#   "abu 'awanah",
#   "ziyad bin 'alaqah",
#   'jarir bin abdullah',
#   "mughirah bin syu'bah"],
#  ['muhammad bin sinan',
#   'fulaih',
#   'ibrahim bin al mundzir',
#   'muhammad bin fulaih',
#   'bapakku',
#   'hilal bin ali',
#   "atho' bin yasar",
#   'abu hurairah'],
#  ["abu an nu'man 'arim bin al fadlal",
#   "abu 'awanah",
#   'abu bisyir',
#   'yusuf bin mahak',
#   "abdullah bin 'amru"],
#  ["qutaibah bin sa'id",
#   "isma'il bin ja'far",
#   'abdullah bin dinar',
#   'ibnu umar'],
#  ['khalid bin makhlad', 'sulaiman', 'abdullah bin dinar', 'ibnu umar'],
#  ['abdullah bin yusuf',
#   'al laits',
#   "sa'id al maqburi",
#   'syarik bin abdullah bin abu namir',
#   'anas bin malik'],
#  ["isma'il bin abdullah",
#   "ibrahim bin sa'd",
#   'shalih',
#   'ibnu syihab',
#   "ubaidullah bin abdullah bin utbah bin mas'ud",
#   "abdullah bin 'abbas"],
#  ['muhammad bin muqotil abu al hasan al marwazi',
#   'abdullah',
#   "syu'bah",
#   'qotadah',
#   'anas bin malik'],
#  ["isma'il",
#   'malik',
#   'ishaq bin abdullah bin abu thalhah',
#   'abu murrah',
#   'abu waqid al laitsi'],
#  ['musaddad',
#   'bisyir',
#   "ibnu 'aun",
#   'ibnu sirin',
#   'abdurrahman bin abu bakrah',
#   'bapaknya'],
#  ['muhammad bin yusuf', 'sufyan', "al a'masy", "abu wa'il", "ibnu mas'ud"],
#  ['muhammad bin basysyar',
#   "yahya bin sa'id",
#   "syu'bah",
#   'abu at tayyah',
#   'anas bin malik'],
#  ['utsman bin abu syaibah', 'jarir', 'manshur', "abu wa'il", 'abdullah'],
#  ["sa'id bin 'ufair",
#   'ibnu wahab',
#   'yunus',
#   'ibnu syihab',
#   'humaid bin abdurrahman',
#   "mu'awiyyah"],
#  ['ali bin abdullah', 'sufyan', 'ibnu abu najih', 'mujahid', 'ibnu umar'],
#  ['al humaidi',
#   'sufyan',
#   "isma'il bin abu khalid",
#   'qais bin abu hazim',
#   "abdullah bin mas'ud"],
#  ['muhammad bin gharair az zuhri',
#   "ya'qub bin ibrahim",
#   'bapakku',
#   'shalih',
#   'ibnu syihab',
#   "'ubaidullah bin abdullah",
#   "ibnu 'abbas",
#   "ubay bin ka'b"],
#  ["abu ma'mar", 'abdul warits', 'khalid', "'ikrimah", "ibnu 'abbas"],
#  ["isma'il bin abu uwais",
#   'malik',
#   'ibnu syihab',
#   "'ubaidullah bin abdullah bin 'utbah",
#   "abdullah bin 'abbas"],
#  ['muhammad bin yusuf',
#   'abu mushir',
#   'muhammad bin harb',
#   'az zubaidi',
#   'az zuhri',
#   "mahmud bin ar rabbi'"],
#  ['abu al qasim khalid bin khali',
#   'muhammad bin harb',
#   "al auza'i",
#   'az zuhri',
#   "'ubaidullah bin abdullah bin 'utbah bin mas'ud",
#   "ibnu 'abbas",
#   "ubay bin ka'b"],
#  ["muhammad bin al 'ala`",
#   'hammad bin usamah',
#   'buraid bin abdullah',
#   'abu burdah',
#   'abu musa'],
#  ["'imran bin maisarah", 'abdul warits', 'abu at tayyah', 'anas bin malik'],
#  ['musaddad', 'yahya', "syu'bah", 'qotadah', 'anas bin malik'],
#  ["sa'id bin 'ufair",
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   'hamzah bin abdullah bin umar',
#   'ibnu umar'],
#  ["isma'il",
#   'malik',
#   'ibnu syihab',
#   "'isa bin thalhah bin ubaidillah",
#   "abdullah bin 'amru bin al 'ash"],
#  ["musa bin isma'il", 'wuhaib', 'ayyub', "'ikrimah", "ibnu 'abbas"],
#  ['al makki bin ibrahim', 'hanzhalah bin abu sufyan', 'salim', 'abu hurairah'],
#  ["musa bin isma'il", 'wuhaib', 'hisyam', 'fatimah', "asma'"],
#  ['muhammad bin basysyar', 'ghundar', "syu'bah", 'abu jamrah', "ibnu 'abbas"],
#  ['muhammad bin muqotil abu al hasan',
#   'abdullah',
#   "umar bin sa'id bin abu husain",
#   'abdullah bin abu mulaikah',
#   "'uqbah bin al harits"],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   'ibnu wahb',
#   'yunus',
#   'ibnu syihab',
#   "'ubaidullah bin abdullah bin abu tsaur",
#   "abdullah bin 'abbas",
#   'umar',
#   'umayyah bin zaid'],
#  ['muhammad bin katsir',
#   'sufyan',
#   'ibnu abu khalid',
#   'qais bin abu hazim',
#   "abu al mas'ud al anshari"],
#  ['abdullah bin muhammad',
#   "abdul malik bin 'amru al 'aqadi",
#   'sulaiman bin bilal al madini',
#   "rabi'ah bin abu abdurrahman",
#   'yazid',
#   'zaid bin khalid al juhani'],
#  ["muhammad bin al 'ala`", 'abu usamah', 'buraid', 'abu burdah', 'abu musa'],
#  ['abu al yaman', "syu'aib", 'az zuhri', 'anas bin malik'],
#  ['abdah',
#   'abdushshamad',
#   'abdullah bin al mutsanna',
#   'tsumamah bin abdullah',
#   'anas'],
#  ["'abdah bin abdullah ash shafar",
#   'abdushshamad',
#   'abdullah bin al mutsanna',
#   'tsumamah bin abdullah',
#   'anas'],
#  ['musaddad',
#   "abu 'awanah",
#   'abu bisyir',
#   'yusuf bin mahak',
#   "abdullah bin 'amru"],
#  ['muhammad ibnu salam',
#   'al muharibi',
#   'shalih bin al hayyan',
#   "'amir asy sya'bi",
#   'abu burdah',
#   'bapaknya'],
#  ['sulaiman bin harb', "syu'bah", 'ayyub', "'atho'", "ibnu 'abbas"],
#  ["abdul 'aziz bin abdullah",
#   'sulaiman',
#   "'amru bin abu 'amru",
#   "sa'id al maqburi",
#   'abu hurairah'],
#  ["isma'il bin abu uwais",
#   'malik',
#   "hisyam bin 'urwah",
#   'bapaknya',
#   "abdullah bin 'amru bin al 'ash"],
#  ['adam',
#   "syu'bah",
#   'ibnu al ashbahani',
#   'abu shalih dzakwan',
#   "abu sa'id al khudri"],
#  ["sa'id bin abu maryam", "nafi' bin umar", 'ibnu abu mulaikah', 'aisyah'],
#  ["'abdullah bin yusuf",
#   'al laits',
#   "sa'id",
#   'abu syuraih',
#   "'amru bin sa'id"],
#  ["'abdullah bin 'abdul wahhab",
#   'hammad',
#   'ayyub',
#   'muhammad',
#   'ibnu abu bakrah',
#   'abu bakrah'],
#  ["'ali bin al ja'd", "syu'bah", 'manshur', "rib'i bin jirasy", "'ali"],
#  ['abu al walid',
#   "syu'bah",
#   "jami' bin syaddad",
#   "'amir bin 'abdullah bin az zubair",
#   'bapaknya',
#   'az zubair'],
#  ["abu ma'mar", "'abdul warits", "'abdul 'aziz", 'anas'],
#  ['makki bin ibrahim', "yazid bin abu 'ubaid", 'salamah'],
#  ['musa', "abu 'awanah", 'abu hushain', 'abu shalih', 'abu hurairah'],
#  ['muhammad bin salam',
#   "waki'",
#   'sufyan',
#   'mutharrif',
#   "asy sya'bi",
#   'abu juhaifah'],
#  ["abu nu'aim al fadll bin dukain",
#   'syaiban',
#   'yahya',
#   'abu salamah',
#   'abu hurairah'],
#  ["'ali bin 'abdullah",
#   'sufyan',
#   "'amru",
#   'wahhab bin munabbih',
#   'saudaranya',
#   'abu hurairah'],
#  ['yahya bin sulaiman',
#   'ibnu wahhab',
#   'yunus',
#   'ibnu syihab',
#   "'ubaidullah bin 'abdullah",
#   "ibnu 'abbas"],
#  ['shadaqah',
#   "ibnu 'uyainah",
#   "ma'mar",
#   'az zuhri',
#   'hind',
#   'ummu salamah',
#   "yahya bin sa'id",
#   'hind'],
#  ["sa'id bin 'ufair",
#   'al laits',
#   "'abdurrahman bin khalid bin musafir",
#   'ibnu syihab',
#   'salim',
#   'abu bakar bin sulaiman bin abu hatsmah',
#   "'abdullah bin 'umar"],
#  ['adam', "syu'bah", 'al hakam', "sa'id bin jubair", "ibnu 'abbas"],
#  ["'abdul 'aziz bin 'abdullah",
#   'malik',
#   'ibnu syihab',
#   "al a'raj",
#   'abu hurairah'],
#  ["ahmad bin abu bakr abu mush'ab",
#   'muhammad bin ibrahim bin dinar',
#   "abu dzi'b",
#   "sa'id al maqburi",
#   'abu hurairah'],
#  ["isma'il",
#   'saudaraku',
#   "ibnu abu dzi'b",
#   "sa'id al maqburi",
#   'abu hurairah'],
#  ['hajjaj', "syu'bah", "'ali bin mudrik", "abu zur'ah bin 'amru", 'jarir'],
#  ["'abdullah bin muhammad",
#   'sufyan',
#   "'amru",
#   "sa'id bin jubair",
#   "ibnu 'abbas",
#   'ibnu abbas',
#   "ubay bin ka'b"],
#  ["'utsman", 'jarir', 'manshur', "abu wa'il", 'abu musa'],
#  ["abu nu'aim",
#   "abdul 'aziz bin abu salamah",
#   'az zuhri',
#   "'isa bin thalhah",
#   "'abdullah bin 'amru"],
#  ['qais bin hafsh',
#   "'abdul wahid",
#   "al a'masy sulaiman bin mihran",
#   'ibrahim',
#   "'alqamah",
#   "'abdullah"],
#  ["'abdullah bin musa",
#   "isra'il",
#   'abu ishaq',
#   'al aswad',
#   'ibnu az',
#   "'aisyah"],
#  ["'ubaidullah bin musa", "ma 'ruf bin kharrabudz", 'abu ath thufail'],
#  ['ishaq bin ibrahim',
#   "mu'adz bin hisyam",
#   'bapakku',
#   'qatadah',
#   'anas bin malik'],
#  ['musaddad', "mu'tamir", 'bapakku', 'anas bin malik'],
#  ['muhammad bin salam',
#   "abu mu'awiyah",
#   "hisyam bin 'urwah",
#   'bapaknya',
#   'zainab',
#   'ummu salamah'],
#  ["isma'il", 'malik', "'abdullah bin dinar", "'abdullah bin 'umar"],
#  ['musaddad',
#   "'abdullah bin daud",
#   "al a'masy",
#   'mundzir ats tsauri',
#   'muhammad al hanafiyah',
#   "'ali bin abu thalib",
#   'miqdad bin al'],
#  ["qutaibah bin sa'id",
#   "al laits bin sa'd",
#   "nafi'",
#   "'abdullah bin 'umar",
#   "'umar bin al"],
#  ['adam', "ibnu abu dzi'b", "nafi'", "ibnu 'umar"],
#  ['ishaq bin ibrahim al hanzhali',
#   'abdurrazaq',
#   "ma'mar",
#   'hammam bin munabbih',
#   'abu hurairah'],
#  ['yahya bin bukair',
#   'al laits',
#   'khalid',
#   "sa'id bin abu hilal",
#   "nu'aim bin al mujmir",
#   'abu hurairah'],
#  ["'ali",
#   'sufyan',
#   'az zuhri',
#   "sa'id bin al musayyab",
#   "'abbad bin tamim",
#   'pamannya'],
#  ["'ali bin 'abdullah", 'sufyan', "'amru", 'kuraib', "ibnu 'abbas"],
#  ["'abdullah bin maslamah",
#   'malik',
#   "musa bin 'uqbah",
#   'kuraib',
#   "ibnu 'abbas",
#   'usamah bin zaid'],
#  ["muhammad bin 'abdurrahman",
#   "abu salamah al khaza'i manshur bin salamah",
#   'ibnu bilal',
#   'zaid bin aslam',
#   "'atha' bin yasar",
#   "ibnu 'abbas"],
#  ["'ali bin 'abdullah",
#   'jarir',
#   'manshur',
#   "salim bin abu al ja'd",
#   'kuraib',
#   "ibnu 'abbas"],
#  ['adam', "syu'bah", "abdul 'aziz bin shuhaib", 'anas'],
#  ["'abdullah bin muhammad",
#   'hasyim bin al qasim',
#   "warqa'",
#   "'ubaidullah bin abu yazid",
#   "ibnu 'abbas"],
#  ['adam',
#   "ibnu abu dzi'b",
#   'az zuhri',
#   "'atha' bin yazid al laitsi",
#   'abu ayyub al anshari'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "yahya bin sa'id",
#   'muhammad bin yahya bin hibban',
#   "wasi' bin hibban",
#   "'abdullah bin 'umar"],
#  ['yahya bin bukair', 'al laits', "'uqail", 'ibnu syihab', 'urwah', "'aisyah"],
#  ['ibrahim bin al mundzir',
#   "anas bin 'iyadl",
#   "'ubaidullah",
#   'muhammad bin yahya bin hibban',
#   "wasi' bin hibban",
#   "'abdullah bin 'umar"],
#  ["ya'qub bin ibrahim",
#   'yazid bin harun',
#   'yahya',
#   'muhammad bin yahya bin hibban',
#   "wasi' bin hibban",
#   "'abdullah bin 'umar"],
#  ["abu al walid hisyam bin 'abdul malik",
#   "syu'bah",
#   "abu mu'adz",
#   'anas bin malik'],
#  ['sulaiman bin harb', "syu'bah", "abu mu'adz", 'anas'],
#  ['muhammad bin basysyar',
#   "muhammad bin ja'far",
#   "syu'bah",
#   "'atha' bin abu maimunah",
#   'anas bin malik'],
#  ["mu'adz bin fadlalah",
#   'hisyam',
#   'yahya bin abu katsir',
#   "'abdullah bin abu qatadah",
#   'bapaknya'],
#  ['muhammad bin yusuf',
#   "al auza'i",
#   'yahya bin abu katsir',
#   "'abdullah bin abu qatadah",
#   'bapaknya'],
#  ['ahmad bin muhammad al makki',
#   "'amru bin yahya bin sa'id bin 'amru al makki",
#   'kakeknya',
#   'abu hurairah'],
#  ["abu nu'aim",
#   'zuhair',
#   'abu ishaq',
#   "'abdurrahman bin aswad",
#   'bapaknya',
#   "'abdullah"],
#  ['muhammad bin yusuf',
#   'sufyan',
#   'zaid bin aslam',
#   "'atha' bin yasar",
#   "ibnu 'abbas"],
#  ["husain bin 'isa",
#   'yunus bin muhammad',
#   'fulaih bin sulaiman',
#   "'abdullah bin abu bakar bin 'amru bin hazm",
#   "'abbad bin tamim",
#   "'abdullah bin zaid"],
#  ["abdul 'aziz bin 'abdullah al uwaisy",
#   "ibrahim bin sa'd",
#   'syihab',
#   "'atha' bin yazid",
#   'humran',
#   "'utsman bin 'affan"],
#  ["'abdan", "'abdullah", 'yunus', 'az zuhri', 'abu idris', 'abu hurairah'],
#  ["'abdullah bin yusuf", 'malik', 'abu az zinad', "al a'raj", 'abu hurairah'],
#  ['musa',
#   "abu 'awanah",
#   'abu bisyir',
#   'yusuf bin mahak',
#   "abdullah bin 'amru"],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "'atha' bin yazid",
#   'humran',
#   "'utsman bin 'affan"],
#  ['adam bin abu iyas', "syu'bah", 'muhammad bin ziyad', 'abu hurairah'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "sa'id al maqbari",
#   "'ubaid bin juraij",
#   "'abdullah bin 'umar",
#   'ibnu juraij?',
#   'ibnu juraij'],
#  ['musaddad', "isma'il", 'khalid', 'hafshah', "ummu 'athiyah"],
#  ["hafsh bin 'umar",
#   "syu'bah",
#   "asy'ats bin sulaim",
#   'bapakku',
#   'masruq',
#   "'aisyah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "ishaq bin 'abdullah bin abu thalhah",
#   'anas bin malik'],
#  ["malik bin isma'il", 'israil', "'ashim", 'ibnu sirin'],
#  ["muhammad bin 'abdurrahim",
#   "sa'id bin sulaiman",
#   "'abbad",
#   "ibnu 'aun",
#   'ibnu sirin',
#   'anas'],
#  ["'abdullah bin yusuf", 'malik', 'abu az zinad', "al a'raj", 'abu hurairah'],
#  ['ishaq',
#   "'abdush shamad",
#   "'abdurrahman bin 'abdullah bin dinar",
#   'bapakku',
#   'abu shalih',
#   'abu hurairah'],
#  ["hafsh bin 'umar",
#   "syu'bah",
#   'ibnu abu as safar',
#   "asy sya'bi",
#   "'adi bin hatim"],
#  ['adam bin abu iyas', "ibnu abu dzi'b", "sa'id al maqburi", 'abu hurairah'],
#  ['abu al walid',
#   "sufyan bin 'uyainah",
#   'az zuhri',
#   "'abbad bin tamim",
#   'pamannya'],
#  ["qutaibah bin sa'id",
#   'jarir',
#   "al a'masy",
#   "mundzir abu ya'la ats tsauri",
#   'muhammad bin al hanafiyah',
#   'ali'],
#  ["sa'd bin hafsh",
#   'syaiban',
#   'yahya',
#   'abu salamah',
#   "'atha bin yasar",
#   'zaid bin khalid',
#   "'utsman bin 'affan"],
#  ['ishaq',
#   'an nadlr',
#   "syu'bah",
#   'al hakam',
#   'dzakwan abu shalih',
#   "abu sa'id al khudri"],
#  ['muhammad bin salam',
#   'yazid bin harun',
#   'yahya',
#   "musa bin 'uqbah",
#   'kuraib',
#   "ibnu 'abbas",
#   'usamah bin zaid'],
#  ["'amru bin 'ali",
#   "'abdul wahhab",
#   "yahya bin sa'id",
#   "sa'd bin ibrahim",
#   "nafi' bin jubair bin muth'im",
#   "'urwah bin al mughirah bin syu'bah",
#   "al mughirah bin syu'bah"],
#  ["isma'il",
#   'malik',
#   'makhramah bin sulaiman',
#   'kuraib',
#   "ibnu 'abbas",
#   "'abdullah bin 'abbas"],
#  ["isma'il", 'malik', "hisyam bin 'urwah", 'fatimah', 'asma` binti abu bakar'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "'amru bin yahya al mazini",
#   'bapaknya',
#   "'abdullah bin zaid"],
#  ['musa',
#   'wuhhaib',
#   "'amru",
#   'bapaknya',
#   "'amru bin abu",
#   "'abdullah bin zaid"],
#  ['adam', "syu'bah", 'al hakam', 'abu juhaifah'],
#  ["'ali bin 'abdullah",
#   "ya'qub bin ibrahim bin sa'd",
#   'bapakku',
#   'shalih',
#   'ibnu syihab',
#   "mahmud bin ar rabi'"],
#  ["'abdurrahman bin yunus",
#   "hatim bin isma'il",
#   "al ja'd",
#   "as sa'ib bin yazid"],
#  ['musaddad',
#   "khalid bin 'abdullah",
#   "'amru bin yahya",
#   'bapaknya',
#   "'abdullah bin zaid"],
#  ['sulaiman bin harb',
#   'wuhhaib',
#   "'amru bin yahya",
#   'bapaknya',
#   "'amru bin abu",
#   "'abdullah bin zaid"],
#  ["'abdullah bin yusuf", 'malik', "nafi'", "'abdullah bin 'umar"],
#  ['abu al walid', "syu'bah", 'muhammad bin al munkadir', 'jabir'],
#  ["'abdullah bin munir", "'abdullah bin bakar", 'humaid', 'anas'],
#  ["muhammad bin al 'ala`", 'abu usamah', 'buraid', 'abu burdah', 'abu musa'],
#  ['ahmad bin yunus',
#   "'abdul 'aziz bin abu salamah",
#   "'amru bin yahya",
#   'bapaknya',
#   "'abdullah bin zaid"],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "'ubaidullah bin 'abdullah bin 'utbah",
#   "'aisyah"],
#  ['khalid bin mukhallad',
#   'sulaiman bin bilal',
#   "'amru bin yahya",
#   'bapaknya',
#   "'abdullah bin zaid"],
#  ['musaddad', 'hammad', 'tsabit', 'anas bin malik'],
#  ["abu nu'aim", "mis'ar", 'ibnu jabar', 'anas'],
#  ['ashbagh bin al faraj al mishri',
#   'ibnu wahhab',
#   "'amru bin al harits",
#   'abu an nadlr',
#   "abu salamah bin 'abdurrahman",
#   "'abdullah bin 'umar",
#   "sa'd bin abu waqash"],
#  ["'amru bin khalid al harrani",
#   'al laits',
#   "yahya bin sa'id",
#   "sa'd bin ibrahim",
#   "nafi' bin jubair",
#   "'urwah bin al mughirah bin syu'bah",
#   "al mughirah bin syu'bah"],
#  ["abu nu'aim",
#   'syaiban',
#   'yahya',
#   'abu salamah',
#   "ja'far bin 'amru bin umayyah al dlamri",
#   'bapaknya'],
#  ["'abdan",
#   "'abdullah",
#   "al auza'i",
#   'yahya',
#   'abu salamah',
#   "ja'far bin 'amru bin umayyah",
#   'bapaknya'],
#  ["abu nu'aim",
#   'zakaria',
#   "'amir",
#   "'urwah bin al mughirah bin syu'bah",
#   'bapaknya'],
#  ["'abdullah bin yusuf",
#   'malik',
#   'zaid bin aslam',
#   "'atha bin yasar",
#   "'abdullah bin 'abbas"],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "ja'far bin 'amru bin umayyah",
#   'bapaknya'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "yahya bin sa'id",
#   'busyair bin yasar',
#   "suwaid bin an nu'man"],
#  ['ashbagh',
#   'ibnu wahhab',
#   "'amru bin al harits",
#   'bukair',
#   'kuraib',
#   'maimunah'],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'abdullah bin 'abdullah bin 'utbah",
#   "ibnu 'abbas"],
#  ["'abdullah bin yusuf", 'malik', "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ["abu ma 'mar", "'abdul warits", 'ayyub', 'abu qilabah', 'anas'],
#  ['muhammad bin yusuf',
#   'sufyan',
#   "'amru bin 'amir",
#   'anas bin malik',
#   'musaddad',
#   'yahya',
#   'sufyan'],
#  ['khalid bin makhlad',
#   'sulaiman bin bilal',
#   "yahya bin sa'id",
#   'busyair bin yasar',
#   "suwaid bin an nu'man"],
#  ["'utsman", 'jarir', 'manshur', 'mujahid', "ibnu 'abbas"],
#  ["ya'qub bin ibrahim",
#   "isma'il bin ibrahim",
#   'rauh bin al qasim',
#   "'atha bin abu maimunah",
#   'anas bin malik'],
#  ['muhammad bin al mutsanna',
#   'muhammad bin hazm',
#   "al a'masy",
#   'mujahid',
#   'thawus',
#   "ibnu 'abbas"],
#  ["musa bin isma'il", 'hammam', 'ishaq', 'anas bin malik'],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "'ubaidullah bin 'abdullah bin 'utbah bin mas'ud",
#   'abu hurairah'],
#  ["'abdan", "'abdullah", "yahya bin sa'id", 'anas bin malik'],
#  ["'abdullah bin yusuf", 'malik', "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   'ibnu syihab',
#   "'ubaidullah bin 'abdullah bin 'utbah",
#   'ummu qais binti mihshan'],
#  ['adam', "syu'bah", "al a'masy", "abu wa'il", 'hudzaifah'],
#  ["'utsman bin abu syaibah", 'jarir', 'manshur', "abu wa'il", 'hudzaifah'],
#  ["muhammad bin 'ar'arah", "syu'bah", 'manshur', "abu wa'il", 'hudzaifah'],
#  ['muhammad bin al mutsanna', 'yahya', 'hisyam', 'fatimah', "asma'"],
#  ['muhammad',
#   'ibnu salam-',
#   "abu mu'awiyah",
#   "hisyam bin 'urwah",
#   'bapaknya',
#   "'aisyah"],
#  ["'abdan",
#   "'abdullah bin al mubarak",
#   "'amru bin maimun al jazari",
#   'sulaiman bin yasar',
#   "'aisyah"],
#  ['qutaibah',
#   'yazid',
#   "'amru",
#   'ibnu maimun-',
#   'sulaiman bin yasar',
#   "'aisyah",
#   'musaddad',
#   "'abdul wahid",
#   "'amru bin maimun",
#   "'aisyah"],
#  ["musa bin isma'il al minqari",
#   "'abdul wahid",
#   "'amru bin maimun",
#   'sulaiman bin yasar'],
#  ["'amru bin khalid",
#   'zuhair',
#   "'amru bin maimun bin mihran",
#   'sulaiman bin yasar',
#   "'aisyah"],
#  ['sulaiman bin harb',
#   'hammad bin zaid',
#   'ayyub',
#   'abu qilabah',
#   'anas bin malik'],
#  ['adam', "syu'bah", 'abu at tayyah yazid bin humaid', 'anas'],
#  ["isma'il",
#   'malik',
#   'ibnu syihab az zuhri',
#   "ubaidullah bin 'abdullah",
#   "ibnu 'abbas",
#   'maimunah'],
#  ["'ali bin 'abdullah",
#   "ma'n",
#   'malik',
#   'ibnu syihab',
#   "ubaidullah bin 'abdullah bin 'utbah bin mas'ud",
#   "ibnu 'abbas",
#   'maimunah'],
#  ['ahmad bin muhammad',
#   "'abdullah",
#   "ma'mar",
#   'hammam bin munabbih',
#   'abu hurairah'],
#  ['abu al yaman',
#   "syu'aib",
#   'abu az zinad',
#   "'abdurrahman bin hurmuz al a'raj",
#   'abu hurairah'],
#  ['abu hurairah)'],
#  ["'abdan",
#   'bapakku',
#   "syu'bah",
#   'abu ishaq',
#   "'amru bin maimun",
#   "'abdullah"],
#  ['muhammad bin yusuf', 'sufyan', 'humaid', 'anas bin malik'],
#  ["'ali bin 'abdullah", 'sufyan', 'az zuhri', 'abu salamah', "'aisyah"],
#  ['muhammad',
#   'ibnu salam-',
#   "sufyan bin 'uyainah",
#   'abu hazm',
#   "sahl bin sa'd as sa'idi"],
#  ["abu an nu'man",
#   'hammad bin zaid',
#   'ghailan bin jarir',
#   'abu burdah',
#   'bapaknya'],
#  ["'utsman bin abu syaibah", 'jarir', 'manshur', "abu wa'il", 'hudzaifah'],
#  ['muhammad bin muqatil',
#   "'abdullah",
#   'sufyan',
#   'manshur',
#   "sa'ad bin 'ubaidah",
#   "al bara' bin 'azib"],
#  ["'abdullah bin yusuf", 'malik', "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ['muhammad bin yusuf',
#   'sufyan',
#   "al a'masy",
#   "salim bin abu al ja'd",
#   'kuraib',
#   "ibnu 'abbas",
#   'maimunah'],
#  ['adam bin abu iyas', "ibnu abu dzi'b", 'az zuhri', "'urwah", "'aisyah"],
#  ["'abdullah bin muhammad",
#   "'abdush shamad",
#   "syu'bah",
#   'abu bakar bin hafsh',
#   'abu salamah',
#   "'aisyah"],
#  ["'abdullah bin muhammad",
#   'yahya bin adam',
#   'zuhair',
#   'abu ishaq',
#   "abu ja'far",
#   'jabir bin abdullah'],
#  ["abu nu'aim", "ibnu 'uyainah", "'amru", 'jabir bin zaid', "ibnu 'abbas"],
#  ["abu nu'aim",
#   'zuhair',
#   'abu ishaq',
#   'sulaiman bin shurad',
#   "jubair bin muth'im"],
#  ['muhammad bin basyar',
#   'ghundar',
#   "syu'bah",
#   'mikhwal bin rasyid',
#   "muhammad bin 'ali",
#   "jabir bin 'abdullah"],
#  ["abu nu'aim",
#   "ma'mar bin yahya bin sam",
#   "abu ja'far",
#   "jabir bin 'abdullah",
#   'hasan bin muhammad',
#   'muhammad bin al'],
#  ["musa bin isma'il",
#   "'abdul wahid",
#   "al a'masy",
#   "salim bin abu al ja'd",
#   'kuraib',
#   "ibnu 'abbas",
#   'maimunah'],
#  ['muhammad bin al mutsanna',
#   "abu 'ashim",
#   'hanzhalah',
#   'al qasim',
#   "'aisyah"],
#  ["'umar bin hafsh bin ghiyats",
#   'bapakku',
#   "al a'masy",
#   'salim',
#   'kuraib',
#   "ibnu 'abbas",
#   'maimunah'],
#  ["'abdullah bin az zubair al humaidi",
#   'sufyan',
#   "al a'masy",
#   "salim bin abu al ja'd",
#   'kuraib',
#   "ibnu 'abbas",
#   'maimunah'],
#  ["'abdullah bin maslamah", 'aflah bin humaid', 'al qasim', "'aisyah"],
#  ['musaddad', 'hammad', 'hisyam', 'bapaknya', "'aisyah"],
#  ['abu al walid', "syu'bah", 'abu bakar bin hafsh', "'urwah", "'aisyah"],
#  ['abu al walid',
#   "syu'bah",
#   "'abdullah bin 'abdullah bin jabr",
#   'anas bin malik'],
#  ['muhammad bin mahbub',
#   "'abdul wahid",
#   "al a'masy",
#   "salim bin abu al ja'd",
#   'kuraib',
#   "ibnu 'abbas",
#   'maimunah'],
#  ["musa bin isma'il",
#   "abu 'awanah",
#   "al a'masy",
#   "salim bin abu al ja'di",
#   'kuraib',
#   "ibnu 'abbas",
#   "maimunah binti al harits  '"],
#  ['muhammad bin basysyar',
#   "ibnu abu 'ady",
#   "syu'bah",
#   'ibrahim bin muhammad bin al muntasyir',
#   'bapaknya',
#   "ibnu 'abbas)",
#   "'aisyah"],
#  ['muhammad bin basysyar',
#   "mu'adz bin hisyam",
#   'bapakku',
#   'qatadah',
#   "anas bin malik  '"],
#  ['abu al walid', "za'idah", 'abi hushain', "abu 'abdurrahman", "'ali"],
#  ["abu an-nu'man",
#   "abu 'awanah",
#   'ibrahim bin muhammad bin al muntasyir',
#   'bapaknya',
#   "'aisyah  '"],
#  ['adam bin abu iyas',
#   "syu'bah",
#   'al hakam',
#   'ibrahim',
#   'al aswad',
#   "'aisyah  '"],
#  ["'abdan", "'abdullah", "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ["yusuf bin 'isa",
#   'al fadlol bin musa',
#   "al a'masy",
#   'salim',
#   'kuraib',
#   "ibnu 'abbas",
#   'maimunah'],
#  ['abdullah bin muhammad',
#   "'utsman bin 'umar",
#   'yunus',
#   'az zuhry',
#   'abu salamah',
#   "abu hurairah  '"],
#  ["'abdan",
#   'abu hamzah',
#   "al a'masy",
#   "salim bin abu al ja'di",
#   'kuraib',
#   "ibnu 'abbas",
#   "maimunah  '"],
#  ['khallad bin yahya',
#   "ibrahim bin nafi'",
#   'al hasan bin muslim',
#   'shafiyah binti syaibah',
#   "'aisyah"],
#  ['ishaq bin nashir',
#   'abdurrazaq',
#   "ma'mar",
#   'hammam bin munabbih',
#   'abu hurairah'],
#  ['abu hurairah'],
#  ["'abdullah bin maslamah bin qa'nab",
#   'malik',
#   'abu an nadlr',
#   'abu murrah',
#   "ummu hani' binti abu thalib"],
#  ["'abdan",
#   "'abdullah",
#   'sufyan',
#   "al a'masy",
#   "salim bin abu al ja'd",
#   'kuraib',
#   "ibnu 'abbas",
#   'maimunah'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "hisyam bin 'urwah",
#   'bapaknya',
#   'zainab binti abu salamah',
#   'ummu salamah'],
#  ["'ali bin 'abdullah",
#   'yahya',
#   'humaid',
#   'bakar',
#   "abu rafi'",
#   'abu hurairah'],
#  ["'abdul a'la bin hammad",
#   "abdul a'la bin abdul a'la",
#   "yazid bin zurai'",
#   "sa'id",
#   'qatadah',
#   'anas bin malik'],
#  ["'ayyasy", "'abdul a'la", 'humaid', 'bakar', "abu rafi'", 'abu hurairah'],
#  ["abu an nu'aim",
#   'hisyam',
#   'syaiban',
#   'yahya bin abu katsir',
#   'abu salamah',
#   "'aisyah"],
#  ['qutaibah', 'al laits', "nafi'", "ibnu 'umar", "'umar bin al"],
#  ['yahya bin bukair',
#   'al laits',
#   "'ubaidullah bin abu ja'far",
#   "muhammad bin 'abdurrahman",
#   "'urwah",
#   "'aisyah"],
#  ["musa bin isma'il", 'juwairiyah', "nafi'", "'abdullah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "'abdullah bin dinar",
#   "'abdullah bin 'umar",
#   "'umar bin al"],
#  ["mu'adz bin fadlalah",
#   'hisyam',
#   "abu nu'aim",
#   'hisyam',
#   'qatadah',
#   'al hasan',
#   "abu rafi'",
#   'abu hurairah'],
#  ["abu ma'mar",
#   "'abdul warits",
#   'al husain',
#   'abu salamah',
#   "'atha' bin yasar",
#   'zaid bin khalid al juhaini',
#   "'utsman bin 'affan"],
#  ['musaddad',
#   'yahya',
#   "hisyam bin 'urwah",
#   'bapakku',
#   'abu ayyub',
#   "ubay bin ka'b"],
#  ["'ali bin 'abdullah",
#   'sufyan',
#   "'abdurrahman bin al qasim",
#   'al qasim bin muhammad',
#   "'aisyah"],
#  ["'abdullah bin yusuf", 'malik', "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ['ibrahim bin musa',
#   'hisyam bin yusuf',
#   'ibnu juraij',
#   "hisyam bin 'urwah",
#   "'urwah",
#   "'aisyah"],
#  ["abu nu'aim al fadll bin dukain",
#   'zuhair',
#   'manshur bin shafiyah',
#   'ibunya',
#   "'aisyah"],
#  ['al makki bin ibrahim',
#   'hisyam',
#   'yahya bin abu katsir',
#   'abu salamah',
#   'zainab binti ummu salamah',
#   'ummu salamah'],
#  ['qabishah', 'sufyan', 'manshur', 'ibrahim', 'al aswad', "'aisyah"],
#  ["isma'il bin khalil",
#   "'ali bin mushir",
#   'abu ishaq',
#   "'abdurrahman bin al aswad",
#   'bapaknya',
#   "'aisyah"],
#  ["abu an nu'man",
#   "'abdul wahid",
#   'asy syaibani',
#   "'abdullah bin syadad",
#   'maimunah'],
#  ["sa'id bin abu maryam",
#   "muhammad bin ja'far",
#   'zaid',
#   'ibnu aslam-',
#   "'iyadl bin 'abdullah",
#   "abu sa'id al khudri"],
#  ["abu nu'aim",
#   "'abdul 'aziz bin abu salamah",
#   "'abdurrahman bin 'abdullah al qasim",
#   'al qasim bin muhammad',
#   "'aisyah"],
#  ["'abdullah bin yusuf", 'malik', "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "hisam bin 'urwah",
#   'fatimah binti al mundzir',
#   "asma' binti abu bakar ash shiddiq"],
#  ['ashbagh',
#   'ibnu wahb',
#   "'amru bin al harits",
#   "'abdurrahman bin al qasim",
#   'bapaknya',
#   "'aisyah"],
#  ['ishaq', "khalid bin 'abdullah", 'khalid', "'ikrimah", "'aisyah"],
#  ['qutaibah', "yazid bin zurai'", 'khalid', "'ikrimah", "'aisyah"],
#  ['musaddad', "mu'tamir", 'khalid', "'ikrimah", "'aisyah"],
#  ["abu nu'aim", "ibrahim bin nafi'", 'ibnu abu najih', 'mujahid', "'aisyah"],
#  ["'abdullah bin 'abdul wahhab",
#   'hammad bin zaid',
#   'ayyub',
#   'hafshah',
#   "abu 'abdullah atau hisyam bin hassan",
#   'hafshah',
#   "ummu 'athiyah"],
#  ['yahya', "ibnu 'uyainah", 'manshur bin shafiyyah', 'ibunya', "'aisyah"],
#  ['muslim bin ibrahim', 'wuhaib', 'manshur', 'ibunya', "'aisyah"],
#  ["musa bin isma'il", 'ibrahim', 'ibnu syihab', "'urwah", "'aisyah"],
#  ["'ubaid bin isma'il", 'abu usamah', 'hisyam', 'bapaknya', "'aisyah"],
#  ['musaddad', 'hammad', "'ubaidullah bin abu bakar", 'anas bin malik'],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'urwah",
#   "'aisyah"],
#  ["'abdullah bin muhammad", 'sufyan', 'hisyam', 'bapaknya', "'aisyah"],
#  ["musa bin isma'il", 'hammam', 'qatadah', "mu'adzah", "'aisyah"],
#  ["sa'd bin hafsh",
#   'syaiban',
#   'yahya',
#   'abu salamah',
#   'zainab binti abu salamah',
#   'ummu salamah'],
#  ["mu'adz bin fadlalah",
#   'hisyam',
#   'yahya',
#   'abu salamah',
#   'zainab binti abu salamah',
#   'ummu salamah'],
#  ['muhammad', 'ibnu salam-', "'abdul wahhab", 'ayyub', 'hafshah'],
#  ["ahmad bin abu raja'",
#   'abu usamah',
#   "hisyam bin 'urwah",
#   'bapakku',
#   "'aisyah"],
#  ["qutaibah bin sa'id", "isma'il", 'ayyub', 'muhammad', "ummu 'athiyyah"],
#  ['ibrahim bin al mundzir',
#   "m'an",
#   "ibnu abu dzi'b",
#   'ibnu syihab',
#   "'urwah",
#   "'amrah",
#   "'aisyah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "'abdullah bin abu bakar bin muhammad bin 'amru bin hazm",
#   'bapaknya',
#   "'amrah binti 'abdurrahman",
#   "'aisyah"],
#  ["mu'alla bin asad",
#   'wuhaib',
#   "'abdullah bin thawus",
#   'bapaknya',
#   "ibnu 'abbas",
#   'ibnu umar'],
#  ['ahmad bin yunus', 'zuhair', "hisyam bin 'urwah", "'urwah", "'aisyah"],
#  ['ahmad bin abu suraij',
#   'syababah',
#   "syu'bah",
#   "husain al mu'alim",
#   "'abdullah bin buraidah",
#   'samrah bin jundub'],
#  ['al hasan bin mudrik',
#   'yahya bin hammad',
#   "abu 'awanah",
#   'sulaiman asy syaibani',
#   "'abdullah bin syaddad",
#   'maimunah'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "'abdurrahman bin al qasim",
#   'bapaknya',
#   "'aisyah"],
#  ['muhammad bin sinan',
#   'husyaim',
#   "sa'id bin an nadlr",
#   'husyaim',
#   'sayyar',
#   'yazid',
#   'ibnu shuhaib',
#   "jabir bin 'abdullah"],
#  ['zakaria bin yahya',
#   "'abdullah bin numair",
#   "hisyam bin 'urwah",
#   'bapaknya',
#   "'aisyah"],
#  ['yahya bin bukair',
#   'al laits',
#   "ja'far bin rabi'ah",
#   "al a'raj",
#   'umair',
#   'ibnu abbas',
#   'abdullah bin yasar'],
#  ['adam',
#   "syu'bah",
#   'al hakam',
#   'dzar',
#   "sa'id bin 'abdurrahman bin abza",
#   'bapaknya',
#   "'ammar bin yasir"],
#  ['hajjaj',
#   "syu'bah",
#   'al hakam',
#   'dzarri',
#   "sa'id bin 'abdurrahman bin abza",
#   'bapaknya',
#   "'ammar",
#   'an nadlar',
#   "syu'bah",
#   'dzarr',
#   'ibnu abdurrahman bin abzaa',
#   'ibnu abdurrahman',
#   'ayahnya',
#   'ammar'],
#  ['sulaiman bin harb',
#   "syu'bah",
#   'al hakam',
#   'dzar',
#   "ibnu 'abdurrahman bin abza",
#   'bapaknya',
#   "'ammar"],
#  ['muhammad bin katsir',
#   "syu'bah",
#   'al hakam',
#   'dzar',
#   "ibnu 'abdurrahman bin abza",
#   "'abdurrahman bin abza",
#   'ammar'],
#  ['muhammad bin basysyar',
#   'ghundar',
#   "syu'bah",
#   'al hakam',
#   'dzarr',
#   "ibnu 'abdurrahman bin abza",
#   'bapaknya',
#   'ammar'],
#  ['musaddad', "yahya bin sa'id", "'auf", "abu raja'", "'imran"],
#  ['bisyr bin khalid',
#   'muhammad',
#   "syu'bah",
#   'sulaiman',
#   "abu wa'il",
#   'abu musa',
#   "'abdullah bin mas'ud"],
#  ['umar bin hafsh',
#   'bapakku',
#   "al a'masy",
#   'syaqiq bin salamah',
#   "'abdullah bin mas'ud",
#   'abu musa',
#   "'ammar"],
#  ['muhammad bin salam',
#   "abu mu'awiyah",
#   "al a'masy",
#   'syaqiq',
#   "'abdullah bin mas'ud",
#   "abu musa al asy'ari",
#   "'ammar"],
#  ["'abdan", "'abdullah", "'auf", "abu raja'", "'imran bin hushain al khaza'i"],
#  ['yahya bin bukair',
#   'al laits',
#   'yunus',
#   'ibnu syihab',
#   'anas bin malik',
#   'abu dzar'],
#  ["'abdullah bin yusuf",
#   'malik',
#   'shalih bin kaisan',
#   "'urwah bin az zubair",
#   "'aisyah"],
#  ["musa bin isma'il", 'yazid bin ibrahim', 'muhammad', "ummu 'athiyah"],
#  ['ahmad bin yunus',
#   "'ashim bin muhammad",
#   'waqid bin muhammad',
#   'muhammad bin al munkadir',
#   'jabir bin samurah'],
#  ["mutharrif abu mush'ab",
#   "'abdurrahman bin abu al mawali",
#   'muhammad bin al munkadir',
#   "jabir bin 'abdullah"],
#  ["'ubaidullah bin musa",
#   "hisyam bin 'urwah",
#   'bapaknya',
#   "'umar bin abu salamah"],
#  ['muhammad bin al mutsanna',
#   'yahya',
#   'hisyam',
#   'bapakku',
#   "'umar bin abu salamah"],
#  ["'ubaid bin isma'il",
#   'abu usamah',
#   'hisyam',
#   'bapaknya',
#   "'umar bin abu salamah"],
#  ["isma'il bin abu uwais",
#   'malik bin anas',
#   'abu an nadlar',
#   'abu murrah',
#   "ummu hani' binti abu thalib"],
#  ["'abdullah bin yusuf",
#   'malik',
#   'ibnu syihab',
#   "sa'id bin al musayyab",
#   'abu hurairah'],
#  ["abu 'ashim",
#   'malik',
#   'abu az zanad',
#   "'abdurrahman al 'raj",
#   'abu hurairah'],
#  ["abu nu'aim", 'syaiban', 'yahya bin abu katsir', "'ikrimah", 'abu hurairah'],
#  ['yahya bin shalih',
#   'fulaih bin sulaiman',
#   "sa'id bin al harits",
#   "jabir bin 'abdullah"],
#  ['musaddad', 'yahya', 'sufyan', 'abu hazim', "sahal bin sa'd"],
#  ['yahya',
#   "abu mu'awiyah",
#   "al a'masy",
#   'muslim',
#   'masruq',
#   "mughirah bin syu'bah"],
#  ['mathar bin al fadlal',
#   'rauh',
#   'zakaria bin ishaq',
#   "'amru bin dinar",
#   "jabir bin 'abdullah"],
#  ['sulaiman bin harb', 'hammad bin zaid', 'ayyub', 'muhammad', 'abu hurairah'],
#  ["'ashim bin 'ali", "ibnu abu dzi'b", 'az zuhri', 'salim', "ibnu 'umar"],
#  ["qutaibah bin sa'id",
#   'laits',
#   'ibnu syihab',
#   "'ubaidullah bin 'abdullah bin 'utbah",
#   "abu sa'id al khudri"],
#  ["qabishah bin 'uqbah", 'sufyan', 'abu az zinad', "al a'raj", 'abu hurairah'],
#  ['ishaq',
#   "ya'qub bin ibrahim",
#   'anak saudara ibnu syihab',
#   'pamannya',
#   "humaid bin 'abdurrahman bin 'auf",
#   'abu hurairah',
#   "humaid bin 'abdurrahman"],
#  ["'abdul aziz bin 'abdullah",
#   'ibnu abu al mawali',
#   'muhammad bin al munkadir',
#   "jabir bin 'abdullah"],
#  ["ya'qub bin ibrahim",
#   "ima'il bin 'ulayyah",
#   "'abdul 'aziz bin shuhaib",
#   'anas bin malik'],
#  ['abu al yaman', "syu'aib", 'az zuhri', "'urwah", "'aisyah"],
#  ['ahmad bin yunus', "ibrahim bin sa'd", 'ibnu syihab', "'urwah", "'aisyah"],
#  ["abu ma'mar 'abdullah bin 'amru",
#   "'abdul warits",
#   "'abdul 'aziz bin shuhaib",
#   'anas bin malik'],
#  ["'abdullah bin yusuf",
#   'al laits',
#   'yazid bin abu habib',
#   'abu al khair',
#   "'uqbah bin 'amir"],
#  ["muhammad bin 'ar'arah",
#   "'umar bin abu za'idah",
#   "'aun bin abu juhaifah",
#   'bapaknya'],
#  ["'ali bin 'abdullah", 'sufyan', 'abu hazim', "sahal bin sa'd"],
#  ["muhammad bin 'abdurrahim",
#   'yazid bin harun',
#   'humaid ath thawil',
#   'anas bin malik'],
#  ['musaddad',
#   'khalid',
#   'sulaiman asy syaibani',
#   "'abdullah bin syidad",
#   'maimunah'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "ishaq bin 'abdullah bin abu thalhah",
#   'anas bin malik'],
#  ['abu al walid',
#   "syu'bah",
#   'sulaiman asy syaibani',
#   "'abdullah bin syaddad",
#   'maimunah'],
#  ["isma'il",
#   'malik',
#   'abu an nadlr',
#   "abu salamah bin 'abdurrahman",
#   "'aisyah"],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'urwah",
#   "'aisyah"],
#  ["'abdullah bin yusuf", 'al laits', 'yazid', "'irak", "'urwah"],
#  ["abu al walid hisyam bin 'abdul malik",
#   'bisyir bin al mufadlal',
#   'ghalib al qaththan',
#   "bakar bin 'abdullah",
#   'anas bin malik'],
#  ['adam bin abu iyas',
#   "syu'bah",
#   "abu maslamah sa'id bin yazid al azdi",
#   'anas bin malik'],
#  ['adam',
#   "syu'bah",
#   "al a'masy",
#   'ibrahim',
#   'hammam bin al harits',
#   "jarir bin 'abdullah"],
#  ['ishaq bin nashr',
#   'abu usamah',
#   "al a'masy",
#   'muslim',
#   'masruq',
#   "al mughirah bin syu'bah"],
#  ['ash shaltu bin muhammad', 'mahdi', 'washil', "abu wa'il", 'hudzaifah'],
#  ['yahya bin bukair',
#   'bakar bin mudlar',
#   "ja'far bin rabi'ah",
#   'ibnu hurmuz',
#   "'abdullah bin malik bin buhainah"],
#  ["'amru bin 'abbas",
#   'ibnu al mahdi',
#   "manshur bin sa'd",
#   'maimun bin siyah',
#   'anas bin malik'],
#  ["nu'aim", 'ibnu al mubarak', 'humaid ath thawil', 'anas bin malik'],
#  ["'ali bin 'abdullah",
#   'sufyan',
#   'az zuhri',
#   "'atha' bin yazid al laitsi",
#   'abu ayyub al anshari'],
#  ['al humaid', 'sufyan', "'amru bin dinar", "ibnu 'umar"],
#  ['musaddad', 'yahya', 'saif', 'mujahid', "ibnu 'umar"],
#  ['ishaq bin nashr', 'abdurrazaq', 'ibnu juraij', "'atha'", "ibnu 'abbas"],
#  ["'abdullah bin raja'", 'israil', 'abu ishaq', "al bara' bin 'azib?  'ma"],
#  ['muslim bin ibrahim',
#   "hisyam bin abu 'abdullah",
#   'yahya bin abu katsir',
#   "muhammad bin 'abdurrahman",
#   "jabir bin 'abdullah"],
#  ["'utsman", 'jarir', 'manshur', 'ibrahim', "'alqamah", 'abdullah'],
#  ["'amru bin 'aun",
#   'husyaim',
#   'humaid',
#   'anas bin malik',
#   "'umar bin al khaththab"],
#  ["'abdullah bin yusuf",
#   'malik bin anas',
#   "'abdullah bin dinar",
#   "'abdullah bin 'umar"],
#  ['musaddad',
#   'yahya',
#   "syu'bah",
#   'al hakam',
#   'ibrahim',
#   "'alqamah",
#   "'abdullah"],
#  ['qutaibah', "isma'il bin ja'far", 'humaid', 'anas bin malik'],
#  ["'abdullah bin yusuf", 'malik', "nafi'", "'abdullah bin 'umar"],
#  ["'abdullah bin yusuf", 'malik', "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ["musa bin isma'il",
#   "ibrahim bin sa'd",
#   'ibnu syihab',
#   "humaid bin 'abdurrahman",
#   'abu hurairah'],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "humaid bin 'abdurrahman",
#   'abu hurairah'],
#  ["hafsh bin 'umar", "syu'bah", 'qatadah', 'anas bin malik'],
#  ['adam', "syu'bah", 'qatadah', 'anas bin malik'],
#  ["'ali bin 'abdullah",
#   'sufyan',
#   'az zuhri',
#   "humaid bin 'abdurrahman",
#   "abu sa'id"],
#  ['adam', "syu'bah", 'qatadah', 'anas bin malik'],
#  ['ishaq bin nashr', 'abdurrazaq', "ma'mar", 'hammam', 'abu hurairah'],
#  ["malik bin isma'il", 'zuhair', 'humaid', 'anas bin malik'],
#  ["'abdullah bin yusuf", 'malik', 'abu az zinad', "al a'raj", 'abu hurairah'],
#  ['yahya bin shalih',
#   'fulaih bin sulaiman',
#   "hilal bin 'ali",
#   'anas bin malik'],
#  ["'abdullah bin yusuf", 'malik', "nafi'", "'abdullah bin 'umar"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "ishaq bin 'abdullah bin abu thalhah",
#   'anas'],
#  ['yahya bin musa',
#   'abdurrazaq',
#   'ibnu juraij',
#   'ibnu syihab',
#   "sahal bin sa'd"],
#  ["'abdullah bin maslamah",
#   "ibrahim bin sa'd",
#   'ibnu syihab',
#   "mahmud bin ar rabi'",
#   "'itban bin malik"],
#  ["sa'id bin 'ufair",
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "mahmud bin ar rabi' al anshari",
#   "'itban bin malik"],
#  ['sulaiman bin harb',
#   "syu'bah",
#   "al asy'ats bin sulaim",
#   'ayahnya',
#   'masruq',
#   "'aisyah"],
#  ['muhammad bin al mutsanna', 'yahya', 'hisyam', 'bapakku', "'aisyah"],
#  ['musaddad', "'abdul warits", 'abu at tayyah', 'anas bin malik'],
#  ['sulaiman bin harb', "syu'bah", 'abu at tayyah', 'anas bin malik'],
#  ['shadaqah bin al fadll',
#   'sulaiman bin hayyan',
#   "'ubaidullah",
#   "nafi'",
#   "ibnu 'umar"],
#  ["'abdullah bin maslamah",
#   'malik',
#   'zaid bin aslam',
#   "'atha' bin yasar",
#   "'abdullah bin 'abbas"],
#  ['musadad', 'yahya', "'ubaidullah bin 'umar", "nafi'", "ibnu 'umar"],
#  ["isma'il bin 'abdullah",
#   'malik',
#   "'abdullah bin dinar",
#   "'abdullah bin 'umar"],
#  ['muhammad bin salam', "'abdah", "hisyam bin 'urwah", 'bapaknya', "'aisyah"],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "ubaidullah bin 'abdullah bin 'utbah",
#   "'aisyah",
#   "'abdullah bin 'abbas"],
#  ["'abdullah bin maslamah",
#   'malik',
#   'ibnu syihab',
#   "sa'in bin al musattab",
#   'abu hurairah'],
#  ['muhammad bin sinan',
#   'husyaim',
#   'sayyarah',
#   'yazid al faqir',
#   "jabir bin 'abdullah"],
#  ["ubaid bin isma'il",
#   'abu usamah',
#   "hisyam bin 'urwah",
#   'bapaknya',
#   "'aisyah"],
#  ['musaddad', 'yahya', "'ubaidullah", "nafi'", "'abdullah bin 'umar"],
#  ["qutaibah bin sa'id",
#   "'abdul 'aziz bin abu hazim",
#   'abu hazim',
#   "sahl bin sa'd"],
#  ["yusuf bin 'isa", 'ibnu fudlail', 'bapaknya', 'abu hazm', 'abu hurairah'],
#  ['khallad bin yahya', "mis'ar", 'muharib bin ditsar', "jabir bin 'abdullah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "'amir bin 'abdullah bin az zubair",
#   "'amru bin sulaim az zaraqi",
#   'abu qatadah as salami'],
#  ["'abdullah bin yusuf", 'malik', 'abu az zanad', "al a'raj", 'abu hurairah'],
#  ["'ali bin 'abdullah",
#   "ya'qub bin ibrahim bin sa'd",
#   'bapakku',
#   'shalih bin kaisan',
#   "nafi'",
#   "'abdullah bin 'umar"],
#  ['musaddad',
#   "'abdul 'aziz bin mukhtar",
#   "khalid al hadza'",
#   "'ikrimah",
#   "ibnu 'abbas",
#   "abu sa'id"],
#  ["qutaibah bin sa'id", "'abdul 'aziz", 'abu hazim', 'sahl'],
#  ['khallad', "'abdul wahid bin aiman", 'bapaknya', "jabir bin 'abdullah"],
#  ['yahya bin sulaiman',
#   'ibnu wahb',
#   "'amru",
#   'bukair',
#   "'ashim bin 'umar bin qatadah",
#   "'ubaidullah al khaulani",
#   "'utsman bin 'affan"],
#  ["qutaibah bin sa'id", 'sufyan', "'amru", "jabir bin 'abdullah"],
#  ["musa bin isma'il",
#   "'abdul wahid",
#   "abu burdah bin 'abdullah",
#   'abu burdah',
#   'bapaknya'],
#  ["abu al yaman al hakam bin nafi'",
#   "syu'aib",
#   'az zuhri',
#   "abu salamah bin 'abdurrahman bin 'auf",
#   'hassan bin tsabit al anshari'],
#  ["'abdul 'aziz bin 'abdullah",
#   "ibrahim bin sa'd",
#   'shalih bin kaisan',
#   'ibnu syihab',
#   "'urwah bin az zubair",
#   "'aisyah"],
#  ["'ali bin 'abdullah", 'sufyan', 'yahya', "'amrah", "'aisyah"],
#  ["'abdullah bin muhammad",
#   "'utsman bin 'umar",
#   'yunus',
#   'az zuhri',
#   "'abdullah bin ka'b bin malik",
#   "ka'b",
#   'ibnu abu'],
#  ['sulaiman bin harb', 'hammad bin zaid', 'tsabit', "rafi'", 'abu hurairah'],
#  ["'abdan", 'abu hamzah', "al a'masy", 'muslim', 'masruq', "'aisyah"],
#  ['ahmad bin waqid', 'hammad bin zaid', 'tsabit', "abu rafi'", 'abu hurairah'],
#  ['ishaq bin ibrahim',
#   'rauh',
#   "muhammad bin ja'far",
#   "syu'bah",
#   'muhammad bin ziyad',
#   'abu hurairah'],
#  ["'abdullah bin yusuf", 'al laits', "sa'id bin abu sa'id", 'abu hurairah'],
#  ['zakaria bin yahya',
#   "'abdullah bin numair",
#   'hisyam',
#   'bapaknya',
#   "'aisyah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "muhammad bin 'abdurrahman bin naufal",
#   "'urwah bin az zubair",
#   'zainab binti abu salamah',
#   'ummu salamah'],
#  ['muhammad bin al mutsanna',
#   "mu'adz bin hisyam",
#   'bapakku',
#   'qatadah',
#   'anas bin malik'],
#  ['muhammad bin sinan',
#   'fulaih',
#   'abu nadlr',
#   "'ubaid bin hunain",
#   "busr bin sa'd",
#   "abu sa'id al khudru"],
#  ["'abdullah bin muhammad al ju'fi",
#   'wahb bin jarir',
#   'bapakku',
#   "ya'la bin hakim",
#   "'ikrimah",
#   "ibnu 'abbas"],
#  ["abu an nu'man", 'hammad bin zaid', 'ayyub', "nafi'", "ibnu 'umar"],
#  ['qutaibah', 'al laits', "sa'id bin abu sa'id", 'abu hurairah'],
#  ["'ali bin 'abdullah",
#   "yahya bin sa'id",
#   "al ju'aid bin 'abdurrahman",
#   'yazid bin khushaifah',
#   "as sa'ib bin yazid",
#   'umar bin al khaththab',
#   "'umar bin al"],
#  ['ahmad',
#   'ibnu wahb',
#   'yunus bin yazid',
#   'ibnu syihab',
#   "'abdullah bin ka'b bin malik",
#   "ka'b bin malik",
#   'ibnu abu'],
#  ['musaddad',
#   'bisyr bin al mufadldlal',
#   "'ubaidullah",
#   "nafi'",
#   "'abdullah bin 'umar"],
#  ["abu an nu'man", 'hammad bin zaid', 'ayyub', "nafi'", "ibnu 'umar"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "ishaq bin 'abdullah bin abu thalhah",
#   'abu murrah',
#   'abu waqid al laitsi'],
#  ["'abdullah bin maslamah",
#   'malik',
#   'ibnu syihab',
#   "'abbad bin tamim",
#   'pamannya'],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'urwah bin az zubair",
#   "'aisyah"],
#  ['musaddad', "abu mu'awanah", "al a'masy", 'abu shalih', 'abu hurairah'],
#  ["hamid bin 'umar", 'bisyr', "'ashim", 'waqid', 'bapaknya', "ibnu 'umar"],
#  ['khallad bin yahya',
#   'sufyan',
#   "abu burdah bin 'abdullah bin abu burdah",
#   'kakeknya',
#   'abu musa'],
#  ['ishaq', 'an nadlr bin syumail', "ibnu 'aun", 'ibnu sirin', 'abu hurairah'],
#  ['muhammad bin abu bakar al muqaddam',
#   'fudlail bin sulaiman',
#   "musa bin 'uqbah",
#   "salim bin 'abdullah",
#   'bapaknya'],
#  ['ibrahim bin al mundzir al hizami',
#   "anas bin 'iyadl",
#   "musa bin 'uqbah",
#   "nafi'",
#   "'abdullah bin 'umar"],
#  ["'abdullah bin yusuf",
#   'malik',
#   'ibnu syihab',
#   "'ubaidullah bin 'abdullah bin 'utbah",
#   "'abdullah bin 'abbas"],
#  ['ishaq',
#   'ibnu manshur-',
#   "'abdullah bin numair",
#   "'ubaidullah bin 'umar",
#   "nafi'",
#   "ibnu 'umar"],
#  ['abu al walid', "syu'bah", "'aun bin abu juhaifah", 'bapakku'],
#  ["'amru bin zurarah",
#   "'abdul 'aziz bin abu hazim",
#   'bapaknya',
#   "sahl bin sa'd"],
#  ['al makki bin ibrahim', "yazid bin abu 'ubaid", 'salamah'],
#  ['musaddad', 'yahya', "'ubaidullah", "nafi'", "'abdullah bin 'umar"],
#  ['adam', "syu'bah", "'aun bin abu juhaifah", 'bapakku'],
#  ["muhammad bin hatim bin bazi'",
#   'syadzan',
#   "syu'bah",
#   "'atha' bin abu maimunah",
#   'anas bin malik'],
#  ['sulaiman bin harb', "syu'bah", 'al hakam', 'abu juhaifah'],
#  ['al makki bin ibrahim', "yazid bin abu 'ubaid", "salamah bin al akwa'"],
#  ['qabishah',
#   'sufyan',
#   "'amru bin 'amir",
#   'anas bin malik',
#   "syu'bah",
#   "'amru",
#   'anas'],
#  ["musa bin isma'il", 'juwairiah', "nafi'", "ibnu 'umar"],
#  ["'abdullah bin yusuf", 'malik', "nafi'", "'abdullah bin 'umar"],
#  ['ibrahim bin al mundzir',
#   'abu dlamrah',
#   "musa bin 'uqbah",
#   "nafi'",
#   "'abdullah bin 'umar",
#   'bilal'],
#  ['muhammad bin abu bakar al muqaddami',
#   "mu'tamir",
#   "'ubaidullah bin 'umar",
#   "nafi'",
#   "ibnu 'umar"],
#  ["'utsman bin abu syaibah",
#   'jarir',
#   'manshur',
#   'ibrahim',
#   'al aswad',
#   "'aisyah"],
#  ["abu ma'mar",
#   "'abdul warits",
#   'yunus',
#   'humaid bin hilal',
#   'abu shalih',
#   "abu sa'id"],
#  ["'abdullah bin yusuf",
#   'malik',
#   'abu an nadlr',
#   "busr bin sa'id",
#   'zaid bin khalid'],
#  ["isma'il bin khalil",
#   "'ali bin mushir",
#   "al a'masy",
#   'muslim',
#   'masruq',
#   "'aisyah"],
#  ['musaddad', 'yahya', 'hisyam', 'bapakku', "'aisyah"],
#  ["'abdullah bin yusuf",
#   'malik',
#   'abu an nadlr',
# ...
#   'yahya',
#   'ibnu abu',
#   'abu salamah',
#   'abu hurairah',
#   "'umar"],
#  ['adam',
#   "ibnu abu dzi'b",
#   "sa'id al maqburi",
#   'bapakku',
#   "ibnu wadi'ah",
#   'salman al farsi'],
#  ['abu al yaman', "syu'aib", 'az zuhri', "ibnu 'abbas"],
#  ['ibrahim bin musa',
#   'hisyam',
#   'ibnu juraij',
#   'ibrahim bin maisarah',
#   'thawus',
#   "ibnu 'abbas"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "nafi'",
#   "'abdullah bin 'umar",
#   "'umar bin al"],
#  ["'abdullah bin yusuf", 'malik', 'abu az zinad', "al a'raj", 'abu hurairah'],
#  ["abu ma'mar", "'abdul warits", "syu'aib bn al habhab", 'anas'],
#  ['muhammad bin katsir',
#   'sufyan',
#   'manshur',
#   'hushain',
#   "abu wa'il",
#   'hudzifah'],
#  ["isma'il",
#   'sulaiman bin bilal',
#   "hisyam bin 'urwah",
#   'bapakku',
#   "'aisyah",
#   "'abdurrahman bin abu"],
#  ["abu nu'aim",
#   'sufyan',
#   "sa'd bin ibrahim",
#   "'abdurrahman",
#   'ibnu hurmuz',
#   'abu hurairah'],
#  ['muhammad bin al mutsanna',
#   "abu 'amir al 'aqadi",
#   'ibrahim bin thahman',
#   "abu jamrah adl dluba'i",
#   "ibnu 'abbas"],
#  ['bisyr bin muhammad al marwazi',
#   "'abdullah",
#   'yunus',
#   'az zuhri',
#   "salim bin 'abdullah",
#   "ibnu 'umar"],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "salim bin 'abdullah",
#   "'abdullah bin 'umar"],
#  ["'abdullah bin maslamah",
#   'malik',
#   'shafwan bin sulaim',
#   "'atha' bin yaar",
#   "abu sa'id al khudri"],
#  ['muslim bin ibrahim', 'wuhaib', 'ibnu thawus', 'bapaknya', 'abu hurairah'],
#  ["'abdullah bin muhammad",
#   'syababah',
#   "warqa'",
#   "'amru bin dinar",
#   'mujahid',
#   "ibnu 'umar"],
#  ['yusuf bin musa',
#   'abu usamah',
#   "'ubaidullah bin 'umar",
#   "nafi'",
#   "ibnu 'umar"],
#  ['musaddad',
#   "isma'il",
#   "'abdul hamid",
#   "'abdullah bin al harits",
#   "ibnu 'abbas"],
#  ['ahmad bin shalih',
#   "'abdullah bin wahab",
#   "'amru bin al harits",
#   "'ubaidullah bin abu ja'far",
#   "muhammad bin ja'far bin az zubair",
#   "'urwah bin az zubair",
#   "'aisyah"],
#  ["'abdan", "'abdullah", "yahya bin sa'id", "'amrah", "aisyah?  'anha"],
#  ["suraij bin an nu'man",
#   'fulaih bin sulaiman',
#   "'utsman bin 'abdurrahman bin 'utsman at taimi",
#   'anas bin malik'],
#  ["'abdan", "'abdullah", 'humaid', 'anas bin malik'],
#  ['muhammad bin abu bakar al muqaddami',
#   "harami bin 'umarah",
#   'abu khaldah',
#   'anas bin malik'],
#  ["'ali bin 'abdullah",
#   'al walid bin muslim',
#   'yazid bin abu maryam al anshari',
#   "'abayah bin rifa'ah",
#   "abu 'abas"],
#  ['adam', "ibnu abu dzi'b", "sa'id", 'abu salamah', 'abu hurairah'],
#  ["'amru bin 'ali",
#   'abu qutaibah',
#   'ibnu al mubarak',
#   'yahya bin abu katsir',
#   "'abdullah bin abu qatadah",
#   'bapaknya'],
#  ["'abdan",
#   "'abdullah",
#   "ibnu abu dzi'b",
#   "sa'id al maqburi",
#   'bapaknya',
#   "ibnu wadi'ah",
#   'salman al farsi'],
#  ['muhammad',
#   'ibnu salam-',
#   'makhlad bin yazid',
#   'ibnu juraij',
#   "nafi'",
#   "ibnu 'umar"],
#  ['adam', "ibnu abu dzi'b", 'az zuhri', "as sa'ib bin yazid"],
#  ["abu nu'aim",
#   "'abdul 'aziz bin abu salamah al majisyun",
#   'az zuhri',
#   "as sa'ib bin yazid"],
#  ['muhammad bin muqatil',
#   "'abdullah",
#   "abu bakar bin 'utsman bin sahl bin hunaif",
#   'abu umamah bin sahl bin hunaif',
#   "mu'awiyyah bin abu suyan"],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "as sa'ib bin yazid"],
#  ['muhammad bin muqatil',
#   "'abdullah",
#   'yunus',
#   'az zuhri',
#   "as sa'ib bin yazid"],
#  ["qutaibah bin sa'id",
#   "ya'qub bin 'abdurrahman bin muhammad bin 'abdullah bin 'abdul qari al qurasyi al iskandarani",
#   'abu hazim bin dinar',
#   "sahl bin sa'd as sa'idi"],
#  ["sa'id bin abu maryam",
#   "muhammad bin ja'far",
#   "yahya bin sa'id",
#   'ibnu anas',
#   "jabir bin 'abdullah"],
#  ['adam bin abu iyas', "ibnu abu dzi'b", 'az zuhri', 'salim', 'bapaknya'],
#  ["'ubaidullah bin 'umar al qawariri",
#   'khalid bin al harits',
#   "'ubaidullah bin 'umar",
#   "nafi'",
#   "ibnu 'umar"],
#  ["mu'adz bin fadlalah",
#   'hisyam',
#   'yahya',
#   'hilal bin abu maimunah',
#   "'atha' bin yasar",
#   "abu sa'id al khudri"],
#  ["muhammad bin ma'mar",
#   "abu 'ashim",
#   'jarir bin hazim',
#   'al hasan',
#   "'amru bin taghlib"],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'urwah",
#   "'aisyah"],
#  ['abu al yaman', "syu'aib", 'az zuhri', "'urwah", "abu humaid as sa'idi"],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "'ali bin husain",
#   'al miswar bin makhramah'],
#  ["isma'il bin aban", 'ibnu al ghasil', "'ikrimah", "ibnu 'abbas"],
#  ['musaddad',
#   'bisyir bin al mufadldlal',
#   "'ubaidullah bin 'umar",
#   "nafi'",
#   "'abdullah bin 'umar"],
#  ['adam',
#   "ibnu abu dzi'b",
#   'az zuhri',
#   "abu 'abdullah al aghar",
#   'abu hurairah'],
#  ["abu an nu'man",
#   'hammad bin zaid',
#   "'amru bin dinar",
#   "jabir bin 'abdullah"],
#  ["'ali bin 'abdullah", 'sufyan', "'amru", 'jabir'],
#  ['musaddad',
#   'hammad bin zaid',
#   "'abdul 'aziz bin shuhaib",
#   'anas',
#   'yunus',
#   'tsabit',
#   'anas'],
#  ['ibrahim bin al mundzir',
#   'al walid bin muslim',
#   "abu 'amru al auza'i",
#   "ishaq bin 'abdullah bin abu thalhah",
#   'anas bin malik'],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "sa'id bin al musayyab",
#   'abu hurairah'],
#  ["'abdullah bin maslamah",
#   'malik',
#   'abu az zinad',
#   "al a'raj",
#   'abu hurairah'],
#  ["mu'awiyah bin 'amru",
#   "za'idah",
#   'hushain',
#   "salim bin abu al ja'd",
#   "jabir bin 'abdullah"],
#  ["'abdullah bin yusuf", 'malik', "nafi'", "'abdullah bin 'umar"],
#  ["sa'id bin abu maryam", 'abu ghassan', 'abu hazim', "sahl bin sa'd"],
#  ["'abdullah bin maslamah", 'ibnu abu hazim', 'bapaknya', 'sahl'],
#  ["muhammad bin 'uqbah 'asy syaibani al kufi",
#   'abu ishaq al fazari',
#   'humaid',
#   'anas'],
#  ["sa'id bin abu maryam", 'abu ghassan', 'abu hazim', "sahl bin sa'd"],
#  ['abu al yaman', "syu'aib", 'az zuhri'],
#  ["sa'id bin yahya bin sa'id al qurasyi",
#   'bapakku',
#   'ibnu juraij',
#   "musa bin 'uqbah",
#   "nafi'",
#   "ibnu 'umar"],
#  ['haiwah bin syuraih',
#   'muhammad bin harb',
#   'az zubaidi',
#   'az zuhri',
#   "'ubaidullah bin 'abdullah bin 'utbah",
#   "ibnu 'abbas"],
#  ["yahya bin ja'fat al bukhari",
#   "waki'",
#   "'ali bin mubarak",
#   'yahya bin abu katsir',
#   'abu salamah',
#   "jabir bin 'abdullah",
#   "'umar bin al"],
#  ["'abdullah bin muhammad bin asma'", 'juwairiyah', "nafi'", "ibnu 'umar"],
#  ['musaddad', 'hammad bin zaid', "'abdul 'aziz bin shuhaib", 'anas bin malik'],
#  ['abu al yaman',
#   "syu'aib",
#   'az zuhri',
#   "salim bin 'abdullah",
#   "'abdullah bin 'umar"],
#  ["ahmad bin 'isa",
#   'ibnu wahb',
#   "'amru",
#   "muhammad bin 'abdurrahman al asadi",
#   "'urwah",
#   "'aisyah"],
#  ['hajjaj', "syu'bah", 'zubaid', "'asy sya'bi", "al bara'"],
#  ["'ubaid bin isma'il", 'abu usamah', 'hisyam', 'bapaknya', "'aisyah"],
#  ["muhammad bin 'abdurrahim",
#   "sa'id bin sulaiman",
#   'husyaim',
#   "'ubaidullah bin abu bakar bin anas",
#   'anas bin malik'],
#  ['musaddad', "isma'il", 'ayyub', 'muhammad bin sirin', 'anas'],
#  ["'utsman", 'jarir', 'manshur', "asy sya'bi", "al bara' bin 'azib"],
#  ["sa'id bin abu maryam",
#   "muhammad bin ja'far",
#   'zaid bin aslam',
#   "'iyadl bin 'abdullah bin abu sarah",
#   "abu sa'id al khudri"],
#  ['ibrahim bin al mundzir',
#   "anas bin 'iyadl",
#   "'ubaidullah",
#   "nafi'",
#   "'abdullah bin 'umar"],
#  ['ibrahim bin musa',
#   'hisyam',
#   'ibnu juraij',
#   "'atha'",
#   "jabir bin 'abdullah"],
#  ["'atha'", "ibnu 'abbas"],
#  ["'atha'", "ibnu 'abbas", "jabir bin 'abdullah"],
#  ["jabir bin 'abdullah"],
#  ["abu 'ashim", 'ibnu juraij', 'al hasan bin muslim', 'thawus', "ibnu 'abbas"],
#  ["ya'qub bin ibrahim", 'abu usamah', "'ubaidullah", "nafi'", "ibnu 'umar"],
#  ['sulaiman bin harb',
#   "syu'bah",
#   "'adi bin tsabit",
#   "sa'id bin jubair",
#   "ibnu 'abbas"],
#  ['adam', "syu'bah", 'zubaid', "asy sya'bi", "al bara' bin 'azib"],
#  ['zakaria bin yahya abu as sukain',
#   'al muharibi',
#   'muhammad bin suqah',
#   "sa'id bin jubair",
#   "ibnu 'umar"],
#  ["ahmad bin ya'qub", "ishaq bin sa'id bin al 'ash", 'bapaknya', "ibnu 'umar"],
#  ['sulaiman bin harb', "syu'bah", 'zubaid', "asy sya'bi", "al bara'"],
#  ["muhammad bin 'ar'arah",
#   "syu'bah",
#   'sulaiman',
#   'muslim al bathin',
#   "sa'id bin jubair",
#   "ibnu 'abbas"],
#  ["abu nu'aim",
#   'malik bin anas',
#   'muhammad bin abu bakar ats tsaqafi',
#   'anas bin malik'],
#  ["'umar bin hafsh", 'bapakku', "'ashim", 'hafshah', "ummu 'athiyyah"],
#  ['muhammad bin basysyar',
#   "'abdul wahhab",
#   "'ubaidullah",
#   "nafi'",
#   "ibnu 'umar"],
#  ['ibrahim bin al mundzir al hizami',
#   'al walid',
#   "abu amru al auza'i",
#   "nafi'",
#   "ibnu 'umar"],
#  ["'abdullah bin 'abdul wahhab",
#   'hammad bin zaid',
#   'ayyub',
#   'muhammad',
#   "ummu 'athiyyah"],
#  ["'amru bin 'abbas",
#   "'abdurrahman",
#   'sufyan',
#   "'abdurrahman bin 'abis",
#   "ibnu 'abbas"],
#  ["abu nu'aim", 'muhammad bin thalhah', 'zubaid', "asy sya'bi", "al bara'"],
#  ['musaddad',
#   "yahya bin sa'id",
#   'sufyan',
#   "'abdurrahman bin 'abis",
#   "ibnu 'abbas"],
#  ['ishaq bin ibrahim bin nashr',
#   'abdurrazaq',
#   'ibnu juraij',
#   "'atha'",
#   "jabir bin 'abdullah"],
#  ['al hasan bin muslim', 'thawus', "ibnu 'abbas"],
#  ["abu ma'mar", "'abdul warits", 'ayyub', 'hafshah binti sirin'],
#  ['muhammad bin al mutsanna',
#   "ibnu abu 'adi",
#   "ibnu 'aun",
#   'muhammad',
#   "ummu 'athiyyah"],
#  ["'abdullah bin yusuf",
#   'al laits',
#   'katsir bin farqad',
#   "nafi'",
#   "ibnu 'umar"],
#  ['musaddad',
#   'abu al ahwash',
#   'manshur bin al mutamir',
#   "asy sya'bi",
#   "al bara' bin 'azib"],
#  ["hamid bin 'umar", 'hammad bin zaid', 'ayyub', 'muhammad', 'anas bin malik'],
#  ['muslim', "syu'bah", 'al aswad', 'jundub'],
#  ['muhammad',
#   'ibnu salam-',
#   'abu tumailah yahya bin wadlih',
#   'fulaih bin sulaiman',
#   "sa'id bin al harits",
#   "jabir bin 'abdullah"],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'urwah",
#   "'aisyah"],
#  ['abu al walid',
#   "syu'bah",
#   "'adi bin tsabit",
#   "sa'id bin jubair",
#   "ibnu 'abbas"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "nafi'",
#   "'abdullah bin dinar",
#   "ibnu 'umar"],
#  ["'abdullah bin maslamah",
#   'malik bin anas',
#   'makhramah bin sulaiman',
#   'kuraib',
#   "ibnu 'abbas"],
#  ['yahya bin sulaiman',
#   "'abdullah bin wahb",
#   "'amru bin al harits",
#   "'abdurrahman bin al qasim",
#   'bapaknya',
#   "'abdullah bin 'umar"],
#  ['abu al yaman', "syu'aib", 'az zuhri', "'urwah", "'aisyah"],
#  ["abu an nu'man", 'hammad bin zaid', 'anas bin sirin', "ibnu 'umar"],
#  ["'umar bin hafsh", 'bapakku', "al a'masy", 'muslim', 'masyruq', "'aisyah"],
#  ['musaddad', 'yahya', 'hisyam', 'bapakku', "'aisyah"],
#  ['musaddad',
#   "yahya bin sa'id",
#   "'ubaidullah",
#   "nafi'",
#   "'abdullah bin 'umar"],
#  ["isma'il",
#   'malik',
#   "abu bakar bin 'umar bin 'abdurrahman bin 'abdullah bin 'umar bin al khaththab",
#   "sa'd bin yasar",
#   "'abdullah bin 'umar",
#   'abdullah bin umar'],
#  ["musa bin isma'il", "juwairiyyah bin asma'", "nafi'", "ibnu 'umar"],
#  ['musaddad',
#   'hammad bin zaid',
#   'ayyub',
#   'muhammad bin sirin',
#   'anas bin malik'],
#  ['musaddad', "'abdul wahid bin ziyad", "'ashim", 'anas bin malik'],
#  ['ahmad bin yunus', "za'idah", 'at taimi', 'abu mijlaz', 'anas bin malik'],
#  ['musaddad', "isma'il", 'khalid', 'abu qilabah', 'anas bin malik'],
#  ["abu nu'aim",
#   'sufyan',
#   "'abdullah bin abu bakar",
#   "'abbad bin tamim",
#   'pamannya'],
#  ['qutaibah',
#   "mughirah bin 'abdurrahman",
#   'abu az zinad',
#   "al a'raj",
#   'abu hurairah'],
#  ["'utsman bin abu syaibah",
#   'jarir',
#   'manshur',
#   'abu adl dluha',
#   'masyruq',
#   "'abdullah"],
#  ["'amru bin 'ali",
#   'abu qutaibah',
#   "'abdurrahman bin 'abdullah bin dinar",
#   'bapaknya',
#   "ibnu 'umar",
#   'salim',
#   'bapaknya'],
#  ['al hasan bin muhammad',
#   "muhammad bin 'abdullah al anshari",
#   "'abdullah bin al mutsanna",
#   "tsumamah bin 'abdullah bin anas",
#   'anas bin malik',
#   "'umar bin al khaththab"],
#  ['ishaq',
#   'wahb bin jarir',
#   "syu'bah",
#   'muhammad bin abu bakar',
#   "'abbad bin tamim",
#   "'abdullah bin zaid"],
#  ["'ali bin 'abdullah",
#   'sufyan',
#   "'abdullah bin abu bakr",
#   "'abbad bin tamim",
#   "'abdullah bin zaid"],
#  ['muhammad',
#   "abu dlamrah anas bin 'iyadl",
#   "syarik bin 'abdullah bin abu namir",
#   'anas bin malik'],
#  ["qutaibah bin sa'id",
#   "isma'il bin ja'far",
#   'syarik',
#   'anas bin malik',
#   "'umar bin al"],
#  ['musaddad', "abu 'awanah", 'qatadah', 'anas bin malik'],
#  ["'abdullah bin maslamah", 'malik', "syarik bin 'abdullah", 'anas bin malik'],
#  ["isma'il", 'malik', "syarik bin 'abdullah bin abu namir", 'anas bin malik'],
#  ['al hasan bin bisyr',
#   "mu'afa bin 'imran",
#   "al auza'i",
#   "ishaq bin 'abdullah bin abu thalhah",
#   'anas bin malik'],
#  ["'abdullah bin yusuf",
#   'malik',
#   "syarik bin 'abdullah bin abu namir",
#   'anas bin malik'],
#  ['muhammad bin katsir',
#   'sufyan',
#   'manshur',
#   "al a'masy",
#   'abu adl dluha',
#   'masyruq',
#   "ibnu mas'ud"],
#  ['muhammad bin abu bakar',
#   "mu'tamir",
#   "'ubaidullah",
#   'tsabit',
#   'anas bin malik'],
#  ['zuhair', 'abu ishaq', "'abdullah bin yazid"],
#  ["syu'aib", 'az zuhri', "'abbad bin tamim", 'pamannya'],
#  ["abu nu'aim", "ibnu abu dzi'b", 'az zuhri', "'abbad bin tamim", 'pamannya'],
#  ['adam', "ibnu abu dzi'b", 'az zuhri', "'abbad bin tamim", 'pamannya'],
#  ["qutaibah bin sa'id",
#   'sufyan',
#   "'abdullah bin abu bakar",
#   "'abbad bin tamim",
#   'pamannya'],
#  ["'abdullah bin muhammad",
#   'sufyan',
#   "'abdullah bin abu bakar",
#   "'abbad bin tamim",
#   'pamannya'],
#  ['muhammad bin salam',
#   "'abdul wahhab",
#   "yahya bin sa'id",
#   'abu bakar bin muhammad',
#   "'abbad bin tamim",
#   "'abdullah bin zaid al anshari"],
#  ['muhammad bin basysyar',
#   'yahya',
#   "ibnu abi 'adi",
#   "sa'id",
#   'qatadah',
#   'anas bin malik'],
#  ['muhammad',
#   'ibnu muqatil',
#   "'abdullah",
#   "'ubaidullah",
#   "nafi'",
#   'al qasim bin muhammad',
#   "'aisyah"],
#  ['muhammad bin muqatil',
#   "'abdullah bin al mubarak",
#   "al auza'i",
#   "ishaq bin 'abdullah bin abu thalhah al anshari",
#   'anas bin malik'],
#  ["sa'id bin abu maryam", "muhammad bin ja'far", 'humaid', 'anas bin malik'],
#  ['muslim', "syu'bah", 'al hakam', 'mujahid', "ibnu 'abbas"],
#  ['abu al yaman',
#   "syu'aib",
#   'abu az zinad',
#   "'abdurrahman al a'raj",
#   'abu hurairah'],
#  ['muhammad bin al mutsanna',
#   'husain bin al hasan',
#   "ibnu 'aun",
#   "nafi'",
#   "ibnu 'umar"],
#  ["isma'il",
#   'malik',
#   'shalih bin kaisan',
#   "'ubaidullah bin 'abdullah bin 'utbah bin mas'ud",
#   'zaid bin khalid al juhaini'],
#  ['muhammad bin yusuf', 'sufyan', "'abdullah bin dinar", "ibnu 'umar"],
#  ["'amru bin 'aun", 'khalid', 'yunus', 'al hasan', 'abu bakrah'],
#  ["syihab bin 'abbad", 'ibrahim bin humaid', "isma'il", 'qais', "abu mas'ud"],
#  ['ashbagh',
#   'ibnu wahb',
#   "'amru",
#   "'abdurrahman bin al qasim",
#   'bapaknya',
#   "ibnu 'umar"],
#  ["'abdullah bin muhammad",
#   'hasyim bin al qasim',
#   "syaiban abu mu'awiyyah",
#   "ziyad bin 'alaqah",
#   "al mughirah bin syu'bah"],
#  ["'abdullah bin maslamah",
#   'malik',
#   "hisyam bin 'urwah",
#   'bapaknya',
#   "'aisyah"],
#  ['ishaq',
#   'yahya bin shalih',
#   "mu'awiyah bin salam bin abu salam al habasyi ad dimsyqi",
#   'yahya bin abu katsir',
#   "abu salamah bin 'abdurrahman bin 'auf az zuhri",
#   "'abdullah bin 'amru"],
#  ['yahya bin bukair',
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   'ahmad bin shalih',
#   "'anbasah",
#   'yunus',
#   "'urwah",
#   "'aisyah"],
#  ["sa'id bin 'ufair",
#   'al laits',
#   "'uqail",
#   'ibnu syihab',
#   "'urwah bin az zubair",
#   "'aisyah"],
#  ["qutaibah bin sa'id", 'hammad bin zaid', 'yunus', 'al hasan', 'abu bakrah'],
#  ["'abdullah bin maslamah",
#   'malik',
#   "yahya bin sa'id",
#   "'amrah binti 'abdurrahman",
#   "'aisyah"],
#  ["abu nu'aim", 'syaiban', 'yahya', 'abu salamah', "'abdullah bin 'amru"],
#  ["'abdullah bin maslamah",
#   'malik',
#   'zaid bin aslam',
#   "'atha bin yasar",
#   "'abdullah bin 'abbas"],
#  ["'abdullah bin yusuf",
#   'malik',
#   "hisyam bin 'urwah",
#   'fatimah binti al mundzir',
#   "asma' binti abu bakar"],
#  ["rabi' bin yahya", "za'idah", 'hisyam', 'fatimah', "asma'"],
#  ["isma'il",
#   'malik',
#   "yahya bin sa'id",
#   "'amrah binti 'abdurrahman",
#   "'aisyah"],
#  ['musaddad', "yahya bin sa'id", "isma'il", 'qais', "ibnu mas'ud"],
#  ["'abdullah bin muhammad",
#   'hisyam',
#   "ma'mar",
#   'az zuhri',
#   "'urwah",
#   "'aisyah"],
#  ["muhammad bin al 'ala",
#   'abu usamah',
#   "buraid bin 'abdullah",
#   'abu burdah',
#   'abu musa'],
#  ['abu al walid', 'zaidah', "ziyad bin 'alaqah", "al mughirah bin syu'bah"],
#  ...]

# %%
len(df.terjemah.tolist())
# Out:
# 7008

# %%
len(perawi)
# Out:
# 7008

# %%
hasil = {'perawi':perawi, 'matan':matan}

# %%
new_df=pd.concat([df,pd.DataFrame(hasil)],axis=1)
new_df
# Out:
#         id           kitab                                               arab  \
# 0        1  shahih_bukhari  حَدَّثَنَا الْحُمَيْدِيُّ عَبْدُ اللَّهِ بْنُ ...
# 1        2  shahih_bukhari  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ يُوسُفَ قَالَ أ...
# 2        3  shahih_bukhari  حَدَّثَنَا يَحْيَى بْنُ بُكَيْرٍ قَالَ حَدَّثَ...
# 3        4  shahih_bukhari  حَدَّثَنَا مُوسَى بْنُ إِسْمَاعِيلَ قَالَ حَدّ...
# 4        5  shahih_bukhari  حَدَّثَنَا عَبْدَانُ قَالَ أَخْبَرَنَا عَبْدُ ...
# ...    ...             ...                                                ...
# 7003  7004  shahih_bukhari  حَدَّثَنَا مُحَمَّدُ بْنُ الْعَلَاءِ حَدَّثَنَ...
# 7004  7005  shahih_bukhari  حَدَّثَنَا هُدْبَةُ بْنُ خَالِدٍ حَدَّثَنَا هَ...
# 7005  7006  shahih_bukhari  حَدَّثَنَا عَلِيٌّ حَدَّثَنَا هِشَامٌ أَخْبَرَ...
# 7006  7007  shahih_bukhari  حَدَّثَنَا أَبُو النُّعْمَانِ حَدَّثَنَا مَهْد...
# 7007  7008  shahih_bukhari  حَدَّثَنِي أَحْمَدُ بْنُ إِشْكَابٍ حَدَّثَنَا ...
#
#                                                terjemah  \
# 0     Telah menceritakan kepada kami [Al Humaidi Abd...
# 1     Telah menceritakan kepada kami [Abdullah bin Y...
# 2     Telah menceritakan kepada kami [Yahya bin Buka...
# 3     Telah menceritakan kepada kami [Musa bin Isma'...
# 4     Telah menceritakan kepada kami [Abdan] dia ber...
# ...                                                 ...
# 7003  Telah menceritakan kepada kami [Muhammad bin A...
# 7004  Telah menceritakan kepada kami [Hudbah bin Kha...
# 7005  Telah menceritakan kepada kami [Ali] telah men...
# 7006  Telah menceritakan kepada kami [Abu Nu'man] te...
# 7007  Telah menceritakan kepadaku [Ahmad bin Isykab]...
#
#                                                  perawi  \
# 0     [al humaidi abdullah bin az zubair, sufyan, ya...
# 1     [abdullah bin yusuf, malik, hisyam bin 'urwah,...
# 2     [yahya bin bukair, al laits, 'uqail, ibnu syih...
# 3     [musa bin isma'il, abu 'awanah, musa bin abu a...
# 4     [abdan, abdullah, yunus, az zuhri, bisyir bin ...
# ...                                                 ...
# 7003  [muhammad bin al 'ala', ibn fudlail, 'umarah, ...
# 7004  [hudbah bin khalid, hammam, qatadah, anas, abu...
# 7005  [ali, hisyam, ma'mar, azzuhri, ahmad bin shali...
# 7006  [abu nu'man, mahdi bin maimun, muhammad bin si...
# 7007  [ahmad bin isykab, muhammad bin fudlail, 'umar...
#
#                                                   matan
# 0     rasulullah shallallahu 'alaihi wasallam bersab...
# 1     rasulullah shallallahu 'alaihi wasallam   waha...
# 2     rasulullah shallallahu 'alaihi wasallam adalah...
# 3     rasulullah shallallahu 'alaihi wasallam sangat...
# 4     rasulullah shallallahu 'alaihi wasallam adalah...
# ...                                                 ...
# 7003  nabi shallallahu 'alaihi wasallam bersabda   a...
# 7004  nabi shallallahu 'alaihi wasallam beliau bersa...
# 7005  nabi shallallahu 'alaihi wasallam tentang duku...
# 7006  nabi shallallahu 'alaihi wasallam beliau bersa...
# 7007  nabi shallallahu 'alaihi wasallam bersabda   a...
#
# [7008 rows x 6 columns]

# %% [markdown]
# # menampilkan wordcloud dari perawi

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
rw=[]
for i in new_df.perawi:
  rw.append(' '.join(i))

# %%
perawi=' '.join(rw).replace('bin','')

# %%
wave_mask = np.array(Image.open("D:/python/bulat2.png"))
wordcloud = WordCloud(background_color="white",mask=wave_mask).generate(perawi)
plt.figure(num=1,facecolor='w',edgecolor='k',figsize=(2,2),dpi=300)
plt.imshow(wordcloud,interpolation="bilinear",aspect="auto");plt.xticks(());plt.yticks(())
plt.margins(x=0,y=0)
plt.title('Wordcloud Nama - Nama Perawi')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Preproccessing matan

# %% [markdown]
# ## menghapus awalan matan yang tidak diperlukan

# %%
def remove_first_word(split_word,word):
    for i in split_word:
        if i == word:
            split_word.remove(word)
            break
    return split_word
def remove_space(split_w):
    for i, w in enumerate(split_w):
        if w == " ":
            split_w.remove(i)
    return split_w

# %%
remove_word = ["rasulullah","nabi",'rasul','bersabda',"shallallahu", "'alaihi","wasallam"]
new_matan = []
for i, matan in enumerate(new_df.matan.tolist()):
    splt = matan.split(' ')
    for i in remove_word:
        splt = remove_first_word(splt,i)
    new_matan.append(' '.join(splt).replace("'","").replace('-',' ').replace('   ',' ').replace('  ',' '))

# %%
new_matan
# Out:
# [' semua perbuatan tergantung niatnya dan (balasan) bagi tiap tiap orang (tergantung) apa yang diniatkan barangsiapa niat hijrahnya karena dunia yang ingin digapainya atau karena seorang perempuan yang ingin dinikahinya maka hijrahnya adalah kepada apa dia diniatkan ',
#  ' wahai rasulullah bagaimana caranya wahyu turun kepada engkau? maka rasulullah shallallahu alaihi wasallam menjawab terkadang datang kepadaku seperti suara gemerincing lonceng dan cara ini yang paling berat buatku lalu terhenti sehingga aku dapat mengerti apa yang disampaikan dan terkadang datang malaikat menyerupai seorang laki laki lalu berbicara kepadaku maka aku ikuti apa yang diucapkannya aisyah berkata sungguh aku pernah melihat turunnya wahyu kepada beliau shallallahu alaihi wasallam pada suatu hari yang sangat dingin lalu terhenti dan aku lihat dahi beliau mengucurkan keringat ',
# Out:
#         id           kitab                                               arab  \
# 0        1  shahih_bukhari  حَدَّثَنَا الْحُمَيْدِيُّ عَبْدُ اللَّهِ بْنُ ...
# 1        2  shahih_bukhari  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ يُوسُفَ قَالَ أ...
# 2        3  shahih_bukhari  حَدَّثَنَا يَحْيَى بْنُ بُكَيْرٍ قَالَ حَدَّثَ...
# 3        4  shahih_bukhari  حَدَّثَنَا مُوسَى بْنُ إِسْمَاعِيلَ قَالَ حَدّ...
# 4        5  shahih_bukhari  حَدَّثَنَا عَبْدَانُ قَالَ أَخْبَرَنَا عَبْدُ ...
# ...    ...             ...                                                ...
# 7003  7004  shahih_bukhari  حَدَّثَنَا مُحَمَّدُ بْنُ الْعَلَاءِ حَدَّثَنَ...
# 7004  7005  shahih_bukhari  حَدَّثَنَا هُدْبَةُ بْنُ خَالِدٍ حَدَّثَنَا هَ...
# 7005  7006  shahih_bukhari  حَدَّثَنَا عَلِيٌّ حَدَّثَنَا هِشَامٌ أَخْبَرَ...
# 7006  7007  shahih_bukhari  حَدَّثَنَا أَبُو النُّعْمَانِ حَدَّثَنَا مَهْد...
# 7007  7008  shahih_bukhari  حَدَّثَنِي أَحْمَدُ بْنُ إِشْكَابٍ حَدَّثَنَا ...
#
#                                                terjemah  \
# 0     Telah menceritakan kepada kami [Al Humaidi Abd...
# 1     Telah menceritakan kepada kami [Abdullah bin Y...
# 2     Telah menceritakan kepada kami [Yahya bin Buka...
# 3     Telah menceritakan kepada kami [Musa bin Isma'...
# 4     Telah menceritakan kepada kami [Abdan] dia ber...
# ...                                                 ...
# 7003  Telah menceritakan kepada kami [Muhammad bin A...
# 7004  Telah menceritakan kepada kami [Hudbah bin Kha...
# 7005  Telah menceritakan kepada kami [Ali] telah men...
# 7006  Telah menceritakan kepada kami [Abu Nu'man] te...
# 7007  Telah menceritakan kepadaku [Ahmad bin Isykab]...
#
#                                                  perawi  \
# 0     [al humaidi abdullah bin az zubair, sufyan, ya...
# 1     [abdullah bin yusuf, malik, hisyam bin 'urwah,...
# 2     [yahya bin bukair, al laits, 'uqail, ibnu syih...
# 3     [musa bin isma'il, abu 'awanah, musa bin abu a...
# 4     [abdan, abdullah, yunus, az zuhri, bisyir bin ...
# ...                                                 ...
# 7003  [muhammad bin al 'ala', ibn fudlail, 'umarah, ...
# 7004  [hudbah bin khalid, hammam, qatadah, anas, abu...
# 7005  [ali, hisyam, ma'mar, azzuhri, ahmad bin shali...
# 7006  [abu nu'man, mahdi bin maimun, muhammad bin si...
# 7007  [ahmad bin isykab, muhammad bin fudlail, 'umar...
#
#                                                   matan
# 0      semua perbuatan tergantung niatnya dan (balas...
# 1      wahai rasulullah bagaimana caranya wahyu turu...
# 2     adalah dengan mimpi yang benar dalam tidur dan...
# 3     sangat kuat keinginannya untuk menghafalkan ap...
# 4     adalah manusia yang paling lembut terutama pad...
# ...                                                 ...
# 7003   allah azza wajalla berfirman siapa yang lebih...
# 7004  beliau perumpamaan orang mukmin yang membaca a...
# 7005  tentang dukun beliau menjawab mereka tidak ada...
# 7006  beliau akan muncul beberapa orang dari arah ti...
# 7007   ada dua kalimat yang disukai ar rahman ringan...
#
# [7008 rows x 6 columns]

# %% [markdown]
# ## Menemukan Matan yang diriwayatkan oleh perawi yang paling banyak muncul

# %%
def find_matan_with_rawi(matan_, perawi):
    index = []
    for i, rawi in enumerate(matan_):
        if perawi in rawi:
            index.append(i)
    return index

# %%
choosed_rawi = ['abu hurairah','ibnu abbas','ibnu syihab']
index_rawi = []
for i in choosed_rawi:
    idx = find_matan_with_rawi(df_fix_matan.matan.tolist(), i)
    index_rawi.append(idx)
abu_hurairah = df_fix_matan[df_fix_matan.id.isin(index_rawi[0])]
ibnu_abbas = df_fix_matan[df_fix_matan.id.isin(index_rawi[1])]
ibnu_syihab = df_fix_matan[df_fix_matan.id.isin(index_rawi[2])]

# %%
abu_hurairah
# Out:
#         id           kitab                                               arab  \
# 43      44  shahih_bukhari  حَدَّثَنَا إِسْمَاعِيلُ قَالَ حَدَّثَنِي مَالِ...
# 95      96  shahih_bukhari  حَدَّثَنَا سُلَيْمَانُ بْنُ حَرْبٍ قَالَ حَدَّ...
# 97      98  shahih_bukhari  حَدَّثَنَا إِسْمَاعِيلُ بْنُ أَبِي أُوَيْسٍ قَ...
# 108    109  shahih_bukhari  حَدَّثَنَا أَبُو نُعَيْمٍ الْفَضْلُ بْنُ دُكَي...
# 113    114  shahih_bukhari  حَدَّثَنَا آدَمُ قَالَ حَدَّثَنَا شُعْبَةُ قَا...
# ...    ...             ...                                                ...
# 6875  6876  shahih_bukhari  حَدَّثَنَا مُعَلَّى بْنُ أَسَدٍ حَدَّثَنَا وُه...
# 6876  6877  shahih_bukhari  حَدَّثَنَا مُحَمَّدُ بْنُ يُوسُفَ حَدَّثَنَا س...
# 6883  6884  shahih_bukhari  حَدَّثَنَا عَبْدَةُ بْنُ عَبْدِ اللَّهِ حَدَّث...
# 6925  6926  shahih_bukhari  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ مُحَمَّدٍ حَدَّ...
# 6946  6947  shahih_bukhari  حَدَّثَنَا قُتَيْبَةُ بْنُ سَعِيدٍ حَدَّثَنَا ...
#
#                                                terjemah  \
# 43    Telah menceritakan kepada kami [Isma'il] Telah...
# 95    Telah menceritakan kepada kami [Sulaiman bin H...
# 97    Telah menceritakan kepada kami [Isma'il bin Ab...
# 108   Telah menceritakan kepada kami [Abu Nu'aim Al ...
# 113   Telah menceritakan kepada kami [Adam] berkata,...
# ...                                                 ...
# 6875  Telah menceritakan kepada kami [Mu'alla bin As...
# 6876  Telah menceritakan kepada kami [Muhammad bin Y...
# 6883  Telah menceritakan kepada kami ['Abdah bin Abd...
# 6925  Telah menceritakan kepada kami [Abdullah bin M...
# 6946  Telah menceritakan kepada kami [Qutaibah bin S...
#
#                                                  perawi  \
# 43    [isma'il, malik bin anas, abu suhail bin malik...
# 95    [sulaiman bin harb, syu'bah, ayyub, 'atho', ib...
# 97    [isma'il bin abu uwais, malik, hisyam bin 'urw...
# 108   [abu nu'aim al fadll bin dukain, syaiban, yahy...
# 113   [adam, syu'bah, al hakam, sa'id bin jubair, ib...
# ...                                                 ...
# 6875  [mu'alla bin asad, wuhaib, sa'id, qatadah, abu...
# 6876  [muhammad bin yusuf, sufyan, 'amru bin yahya, ...
# 6883  ['abdah bin abdullah, husain al ju'fi, zaidah,...
# 6925  [abdullah bin muhammad, ibn uyainah, 'amru, ab...
# 6946  [qutaibah bin sa'id, mughirah bin abdurrahman,...
#
#                                                   matan
# 43    seorang dari penduduk najed dalam keadaan kepa...
# 95     sedang menurut atho dia berkata aku menyaksik...
# 97     sesungguhnya allah tidaklah mencabut ilmu sek...
# 108   beliau lalu naik kendaraannya dan berkhutbah s...
# 113   dan saat itu nabi shallallahu alaihi wasallam ...
# ...                                                 ...
# 6875  memanjatkan doa laa ilaaha illallahul aliimul ...
# 6876  beliau pada hari kiamat semua manusia pingsan ...
# 6883  shallallahualaihiwasallam menemui kami di mala...
# 6925  terus mengepung penduduk thaif dan belum bisa ...
# 6946   allah berfirman jika seorang hamba ku ingin m...
#
# [188 rows x 6 columns]

# %%
ibnu_abbas
# Out:
#         id           kitab                                               arab  \
# 2        3  shahih_bukhari  حَدَّثَنَا يَحْيَى بْنُ بُكَيْرٍ قَالَ حَدَّثَ...
# 94      95  shahih_bukhari  أَخْبَرَنَا مُحَمَّدٌ هُوَ ابْنُ سَلَامٍ حَدَّ...
# 109    110  shahih_bukhari  حَدَّثَنَا عَلِيُّ بْنُ عَبْدِ اللَّهِ قَالَ ح...
# 112    113  shahih_bukhari  حَدَّثَنَا سَعِيدُ بْنُ عُفَيْرٍ قَالَ حَدَّثَ...
# 133    134  shahih_bukhari  حَدَّثَنَا عَلِيٌّ قَالَ حَدَّثَنَا سُفْيَانُ ...
# ...    ...             ...                                                ...
# 6596  6597  shahih_bukhari  حَدَّثَنَا عَبْدَانُ أَخْبَرَنِي أَبِي عَنْ شُ...
# 6695  6696  shahih_bukhari  حَدَّثَنِي عَبْدُ اللَّهِ بْنُ مُحَمَّدٍ حَدَّ...
# 6696  6697  shahih_bukhari  حَدَّثَنَا عَلِيُّ بْنُ عَبْدِ اللَّهِ حَدَّثَ...
# 6778  6779  shahih_bukhari  حَدَّثَنَا سُلَيْمَانُ بْنُ حَرْبٍ حَدَّثَنَا ...
# 6968  6969  shahih_bukhari  حَدَّثَنَا أَبُو الْيَمَانِ أَخْبَرَنَا شُعَيْ...
#
#                                                terjemah  \
# 2     Telah menceritakan kepada kami [Yahya bin Buka...
# 94    Telah mengabarkan kepada kami [Muhammad Ibnu S...
# 109   Telah menceritakan kepada kami ['Ali bin 'Abdu...
# 112   Telah menceritakan kepada kami [Sa'id bin 'Ufa...
# 133   Telah menceritakan kepada kami ['Ali] berkata,...
# ...                                                 ...
# 6596  Telah menceritakan kepada kami ['Abdan] telah ...
# 6695  Telah menceritakan kepadaku [Abdullah bin Muha...
# 6696  Telah menceritakan kepada kami ['Ali bin Abdul...
# 6778  Telah menceritakan kepada kami [Sulaiman bin H...
# 6968  Telah menceritakan kepada kami [Abul Yaman] te...
#
#                                                  perawi  \
# 2     [yahya bin bukair, al laits, 'uqail, ibnu syih...
# 94    [muhammad ibnu salam, al muharibi, shalih bin ...
# 109   ['ali bin 'abdullah, sufyan, 'amru, wahhab bin...
# 112   [sa'id bin 'ufair, al laits, 'abdurrahman bin ...
# 133   ['ali, sufyan, az zuhri, sa'id bin al musayyab...
# ...                                                 ...
# 6596  ['abdan, ayahku, syu'bah, 'abdul malik, rib'i,...
# 6695  [abdullah bin muhammad, mu'awiyah bin umar, ab...
# 6696  ['ali bin abdullah, sufyan, abu az zanad, al q...
# 6778  [sulaiman bin harb, hammad, ayyub, muhammad, a...
# 6968  [abul yaman, syu'aib, azzuhri, 'ubaidullah bin...
#
#                                                   matan
# 2     adalah dengan mimpi yang benar dalam tidur dan...
# 94     ada tiga orang yang akan mendapat pahala dua ...
# 109   yang lebih banyak hadisnya dibandingkan aku ke...
# 112   shalat isya bersama kami di akhir hayatnya set...
# 133   bahwa seakan akan ia mendapatkan sesuatu dalam...
# ...                                                 ...
# 6596  tentang dajjal ia membawa air dan api yang kel...
# 6695   jangan kalian mengharapkan bertemu musuh dan ...
# 6696  dalam sabdanya kalaulah aku merajam seorang wa...
# 6778  hingga kamar aisyah dengan setengah pingsan la...
# 6968  kalian adalah berita paling baru tentang allah...
#
# [173 rows x 6 columns]

# %%
ibnu_syihab
# Out:
#         id           kitab                                               arab  \
# 1        2  shahih_bukhari  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ يُوسُفَ قَالَ أ...
# 153    154  shahih_bukhari  حَدَّثَنَا حُسَيْنُ بْنُ عِيسَى قَالَ حَدَّثَن...
# 166    167  shahih_bukhari  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ يُوسُفَ عَنْ مَ...
# 334    335  shahih_bukhari  بَاب حَدَّثَنَا عَبْدَانُ قَالَ أَخْبَرَنَا عَ...
# 405    406  shahih_bukhari  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ مَسْلَمَةَ قَال...
# ...    ...             ...                                                ...
# 6331  6332  shahih_bukhari  حَدَّثَنَا عَاصِمُ بْنُ عَلِيٍّ حَدَّثَنَا ابْ...
# 6343  6344  shahih_bukhari  حَدَّثَنَا يَحْيَى بْنُ سُلَيْمَانَ حَدَّثَنِي...
# 6456  6457  shahih_bukhari  حَدَّثَنَا عُبَيْدُ بْنُ إِسْمَاعِيلَ حَدَّثَن...
# 6631  6632  shahih_bukhari  حَدَّثَنَا يَحْيَى حَدَّثَنَا عَبْدُ الرَّزَّا...
# 6657  6658  shahih_bukhari  حَدَّثَنَا مُحَمَّدٌ أَخْبَرَنَا عَبْدَةُ حَدّ...
#
#                                                terjemah  \
# 1     Telah menceritakan kepada kami [Abdullah bin Y...
# 153   Telah menceritakan kepada kami [Husain bin 'Is...
# 166   Telah menceritakan kepada kami ['Abdullah bin ...
# 334   Bab. Telah menceritakan kepada kami ['Abdan] b...
# 405   Telah menceritakan kepada kami ['Abdullah bin ...
# ...                                                 ...
# 6331  Telah menceritakan kepada kami ['Ashim bin 'Al...
# 6343  Telah menceritakan kepada kami [Yahya bin Sula...
# 6456  Telah menceritakan kepada kami [Ubaid bin Isma...
# 6631  Telah menceritakan kepada kami [Yahya] telah m...
# 6657  Telah menceritakan kepada kami [Muhammad] Tela...
#
#                                                  perawi  \
# 1     [abdullah bin yusuf, malik, hisyam bin 'urwah,...
# 153   [husain bin 'isa, yunus bin muhammad, fulaih b...
# 166   ['abdullah bin yusuf, malik, abu az zinad, al ...
# 334   ['abdan, 'abdullah, 'auf, abu raja', 'imran bi...
# 405   ['abdullah bin maslamah, ibrahim bin sa'd, ibn...
# ...                                                 ...
# 6331  ['ashim bin 'ali, ibnu abi dzi'b, az zuhri, ub...
# 6343  [yahya bin sulaiman, ibnu wahb, amru, bukair, ...
# 6456  [ubaid bin isma'il, abu usamah, hisyam, ayahny...
# 6631  [yahya, abdurrazaq, ibnu juraij, ibnu syihab, ...
# 6657  [muhammad, 'abdah, hisyam bin urwah, ayahnya, ...
#
#                                                   matan
# 1      wahai rasulullah bagaimana caranya wahyu turu...
# 153                         berwudlu dua kali dua kali
# 166    jika anjing menjilat bejana seorang dari kali...
# 334   melihat seorang menyendiri dan tidak ikut shal...
# 405   mendatanginya di rumahnya seraya mana tempat d...
# ...                                                 ...
# 6331  yang ketika itu beliau sedang duduk ia berseru...
# 6343   janganlah kalian menjilid diatas sepuluh camb...
# 6456  shallallahualaihiwasallam sangat menyukai maka...
# 6631  dan berujar bagaimana pendapat anda sekiranya ...
# 6657  pernah mempekerjakan ibnul atabiyah untuk meng...
#
# [77 rows x 6 columns]

# %% [markdown]
# # Topik Modelling

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from sklearn.feature_extraction.text import CountVectorizer

# %%
def print_Topics(model, feature_name, Top_Topics, n_top_words):
    for topic_idx, topic in enumerate(model.components_[:Top_Topics]):
        print("Topic #%d:" %(topic_idx+1))
        print(" ".join([feature_name[i]
                       for i in topic.argsort()[:-n_top_words - 1: -1]]))

# %%
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# %% [markdown]
# ## Abu Hurairah

# %%
abu_hurairah['rmvstop'] = abu_hurairah['matan'].apply(lambda text: stopword.remove(text))
# Out:
# <ipython-input-25-6fe900f7b3de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abu_hurairah['rmvstop'] = abu_hurairah['matan'].apply(lambda text: stopword.remove(text))

# %%
abu_hurairah.rmvstop.head()
# Out:
# 43     seorang penduduk najed keadaan kepalanya penuh...
# 95      sedang atho berkata aku menyaksikan ibnu abba...
# 97      sesungguhnya allah tidaklah mencabut ilmu sek...
# 108    beliau lalu naik kendaraannya berkhutbah sesun...
# 113    saat nabi shallallahu alaihi wasallam bersaman...
# Name: rmvstop, dtype: object

# %%
PrcsLDA = abu_hurairah['rmvstop']
tf_vectorizer = CountVectorizer(max_df = 1.0, min_df = 1)
tf = tf_vectorizer.fit_transform(PrcsLDA)
tf_terms = tf_vectorizer.get_feature_names()

# %%
n_topics = 5
lda = LDA(n_components = n_topics, learning_method = 'batch', random_state = 0).fit(tf)

# %%
Top_Words = 10
print('Printing top {0} Topics, with top {1} Words:'.format(n_topics, Top_Words))
print_Topics(lda, tf_terms, n_topics, Top_Words)
# Out:
# Printing top 5 Topics, with top 10 Words:
# Topic #1:
# akan pemimpin jawaban pertanggung diminta atas aku seorang dia kalian
# Topic #2:
# aku kosong kalian beliau shalat tidak abu itu paling wasallam
# Topic #3:
# orang berkata aku allah lalu kalian beliau hingga abu kemudian
# Topic #4:
# beliau aku orang kemudian allah engkau berkata alaihi shallallahu wasallam
# Topic #5:
# orang berkata beliau allah lalu alaihi wasallam shallallahu rasulullah aku

# %% [markdown]
# ## Ibnu Abbas

# %%
ibnu_abbas['rmvstop'] = ibnu_abbas['matan'].apply(lambda text: stopword.remove(text))
# Out:
# <ipython-input-30-8b491c6f1fdc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ibnu_abbas['rmvstop'] = ibnu_abbas['matan'].apply(lambda text: stopword.remove(text))

# %%
ibnu_abbas.rmvstop.head()
# Out:
# 2      mimpi benar tidur tidaklah beliau bermimpi dat...
# 94      tiga orang akan mendapat pahala kali seseoran...
# 109    lebih banyak hadisnya dibandingkan aku abdulla...
# 112    shalat isya bersama di akhir hayatnya selesai ...
# 133    seakan ia mendapatkan dalam shalatnya beliau l...
# Name: rmvstop, dtype: object

# %%
PrcsLDA = ibnu_abbas['rmvstop']
tf_vectorizer = CountVectorizer(max_df = 1.0, min_df = 1)
tf = tf_vectorizer.fit_transform(PrcsLDA)
tf_terms = tf_vectorizer.get_feature_names()

# %%
n_topics = 5
lda = LDA(n_components = n_topics, learning_method = 'batch', random_state = 0).fit(tf)

# %%
Top_Words = 10
print('Printing top {0} Topics, with top {1} Words:'.format(n_topics, Top_Words))
print_Topics(lda, tf_terms, n_topics, Top_Words)
# Out:
# Printing top 5 Topics, with top 10 Words:
# Topic #1:
# aku berkata musa lalu kemudian jibril salam menjawab nabi orang
# Topic #2:
# berkata allah musa kamu laki beliau kosong sedang khidir orang
# Topic #3:
# orang beliau tidak berkata abu aku allah al kemudian shalat
# Topic #4:
# aku beliau berkata orang abu rasulullah wasallam shallallahu alaihi bin
# Topic #5:
# beliau aku berkata orang shallallahu wasallam alaihi allah kemudian lalu

# %% [markdown]
# ## Ibnu Syihab

# %%
ibnu_syihab['rmvstop'] = ibnu_syihab['matan'].apply(lambda text: stopword.remove(text))
# Out:
# <ipython-input-35-3e681222370e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ibnu_syihab['rmvstop'] = ibnu_syihab['matan'].apply(lambda text: stopword.remove(text))

# %%
ibnu_syihab.rmvstop.head()
# Out:
# 1       wahai rasulullah bagaimana caranya wahyu turu...
# 153                                  berwudlu kali kali
# 166     anjing menjilat bejana seorang kalian hendakl...
# 334    melihat seorang menyendiri tidak ikut shalat b...
# 405    mendatanginya rumahnya mana tempat rumahmu kau...
# Name: rmvstop, dtype: object

# %%
PrcsLDA = ibnu_syihab['rmvstop']
tf_vectorizer = CountVectorizer(max_df = 1.0, min_df = 1)
tf = tf_vectorizer.fit_transform(PrcsLDA)
tf_terms = tf_vectorizer.get_feature_names()

# %%
n_topics = 5
lda = LDA(n_components = n_topics, learning_method = 'batch', random_state = 0).fit(tf)

# %%
Top_Words = 10
print('Printing top {0} Topics, with top {1} Words:'.format(n_topics, Top_Words))
print_Topics(lda, tf_terms, n_topics, Top_Words)
# Out:
# Printing top 5 Topics, with top 10 Words:
# Topic #1:
# orang beliau berkata seorang mereka kalian aku keduanya yang kamu
# Topic #2:
# kalian aku orang allah abu bakar kemudian laki berkata bin
# Topic #3:
# aku beliau orang khubaib bin allah berkata al mereka ashim
# Topic #4:
# orang aku rasulullah alaihi wasallam shallallahu allah berkata lalu laki
# Topic #5:
# beliau shalat aku berkata lalu kemudian orang tidak rakaat bertanya

# %% [markdown]
# # Abu Hurairah
# ### Abu Hurairah (lahir sekitar tahun 603 Masehi di Daus, Yaman, dan wafat pada tahun 678 Masehi) adalah seorang sahabat Nabi Muhammad SAW yang terkenal. Berikut beberapa unsur biodata Abu Hurairah yang Anda cari:
#
# ### 1. **Tempat Lahir:**
#    ### - Abu Hurairah lahir di Daus, Yaman.
#
# ### 2. **Masa Hidup:**
#    ### - Abu Hurairah hidup sekitar tahun 603 M hingga 678 M.
#
# ### 3. **Bersama Rasulullah:**
#    ### - Abu Hurairah menjadi sahabat Nabi Muhammad SAW pada masa akhir kehidupan Nabi. Dia masuk Islam pada tahun ke-7 Hijriah.
#
# ### 4. **Lama Bersama Rasulullah:**
#    ### - Abu Hurairah bersama Rasulullah SAW selama kurang lebih empat tahun.
#
# ### 5. **Hidup pada Masa Khalifah:**
#    ### -Abu Hurairah hidup pada masa kekhalifahan beberapa khalifah.
#    ### - Khalifah Abu Bakar As-Siddiq (632-634 M).
#    ### - Khalifah Umar bin Khattab (634-644 M).
#    ### - Khalifah Utsman bin Affan (644-656 M).
#    ### - Khalifah Ali bin Abi Thalib (656-661 M).
#
# ### 6. **Jabatan:**
#    ### - Tidak ada catatan khusus tentang jabatan tertentu yang dipegang oleh Abu Hurairah pada masa pemerintahan khalifah. Namun, dia terus mengabdikan dirinya untuk menyampaikan hadis-hadis Nabi Muhammad SAW dan menjadi salah satu perawi hadis terkemuka di antara para sahabat.
#
# ### Perlu diingat bahwa informasi ini bersumber dari sejarah Islam dan hadis-hadis yang diriwayatkan oleh Abu Hurairah sendiri. Sebaiknya, Anda juga memeriksa sumber-sumber sejarah Islam untuk mendapatkan informasi yang lebih lengkap dan akurat.

# %% [markdown]
# # Ibnu Abbas
# ### Ibnu Abbas (lahir sekitar tahun 619 Masehi di Mekah) adalah seorang sahabat Nabi Muhammad SAW dan seorang ulama besar dalam Islam. Berikut adalah beberapa unsur biodata Ibnu Abbas:
#
# ### 1. **Tempat Lahir:**
#    ### - Ibnu Abbas lahir di Mekah.
#
# ### 2. **Masa Hidup:**
#    ### - Ibnu Abbas hidup sekitar tahun 619 M hingga 687 M.
#
# ### 3. **Bersama Rasulullah:**
#    ### - Ibnu Abbas adalah sepupu Rasulullah SAW, dan ia menjadi sahabat Nabi Muhammad SAW sejak usia muda. Dia menjadi sahabat Nabi pada masa awal dakwah.
#
# ### 4. **Lama Bersama Rasulullah:**
#    ### - Ibnu Abbas bersama Rasulullah SAW selama kurang lebih sepuluh tahun, dan dia mendapatkan banyak ilmu dari beliau.
#
# ### 5. **Hidup pada Masa Khalifah:**
#    ### - Ibnu Abbas hidup pada masa kekhalifahan beberapa khalifah.
#    ### - Khalifah Abu Bakar As-Siddiq (632-634 M).
#    ### - Khalifah Umar bin Khattab (634-644 M).
#    ### - Khalifah Utsman bin Affan (644-656 M).
#    ### - Khalifah Ali bin Abi Thalib (656-661 M).
#
# ### 6. **Jabatan:**
#    ### - Ibnu Abbas tidak memegang jabatan pemerintahan selama masa kekhalifahan. Namun, dia sangat dihormati sebagai seorang ulama dan penafsir Al-Qur'an. Dia dikenal sebagai "Tarjuman al-Qur'an" atau penerjemah Al-Qur'an karena keahliannya dalam menafsirkan kitab suci Islam. Ibnu Abbas juga menjadi salah satu sumber utama ilmu tafsir dalam tradisi Islam.
#
# ### Demikianlah beberapa unsur biodata Ibnu Abbas. Informasi ini didasarkan pada sumber-sumber sejarah Islam dan hadis-hadis yang diriwayatkan oleh Ibnu Abbas sendiri. Sebaiknya, Anda juga memeriksa sumber-sumber sejarah Islam untuk mendapatkan informasi yang lebih lengkap dan akurat.

# %% [markdown]
# # Ibnu Syihab
# ### Ibnu Syihab al-Zuhri (wafat tahun 742 M) adalah seorang ulama besar dalam sejarah Islam yang terkenal sebagai ahli hadis dan sejarawan. Dia memiliki peran penting dalam mengumpulkan dan meriwayatkan hadis-hadis Nabi Muhammad SAW. Berikut adalah beberapa unsur biodata Ibnu Syihab al-Zuhri:
#
# ### 1. **Tempat Lahir:**
#    ### - Ibnu Syihab al-Zuhri lahir di Madinah, Arab Saudi.
#
# ### 2. **Masa Hidup:**
#    ### - Ibnu Syihab al-Zuhri hidup pada abad ke-8, dan ia wafat pada tahun 742 M.
#
# ### 3. **Bersama Rasulullah:**
#    ### - Ibnu Syihab al-Zuhri tidak hidup pada masa Nabi Muhammad SAW. Namun, ia adalah seorang ulama dan ahli hadis yang hidup pada generasi sesudah periode kenabian.
#
# ### 4. **Hidup pada Masa Khalifah:**
#    ### - Ibnu Syihab al-Zuhri hidup pada masa kekhalifahan beberapa khalifah. Namun, karena ia lahir setelah wafatnya Nabi Muhammad SAW, dia tidak hidup pada masa kekhalifahan langsung Nabi.
#
# ### 5. **Jabatan:**
#    ### - Ibnu Syihab al-Zuhri adalah seorang ulama dan ahli hadis terkemuka. Dia dikenal sebagai salah satu perawi hadis yang paling terkenal pada zamannya. Pencapaiannya terbesar adalah kontribusinya dalam pengumpulan dan penulisan hadis-hadis Nabi.
#
# ### Ibnu Syihab al-Zuhri memiliki banyak murid dan pernah menjadi guru bagi sejumlah ulama terkemuka. Karya-karyanya dalam bidang hadis dan sejarah Islam menjadi warisan berharga bagi umat Islam.
#
# ### Harap diingat bahwa informasi ini bersumber dari literatur sejarah dan hadis. Sebaiknya, Anda juga memeriksa sumber-sumber sejarah dan hadis Islam untuk mendapatkan informasi yang lebih lengkap dan akurat.
